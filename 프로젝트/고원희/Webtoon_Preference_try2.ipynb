# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
starttime = time.time()

# code

# end code

time.time() - starttime
# Out:
# 0.0

# %%
nick=input(str("닉네임을 입력해 주세요: "))
gender=input(str("성별을 입력해 주세요: "))
age=input(str("나이를 입력해 주세요: "))

users_dict={'nick':[nick],
            'gender':[gender],
            'age':[age]
           }

df=pd.DataFrame(users_dict)
df.to_csv('users_info.csv', index=False,header=False,mode='a')

# %%
#네이버 툰의 title_list 생성
def get_naverToon_info():
    
    naverToon_url="https://comic.naver.com/webtoon/creation.nhn"
    naver_resp=requests.get(naverToon_url)
    naver_soup=BeautifulSoup(naver_resp.content,'html.parser')
    all_list=naver_soup.find('div', class_="all_list").find_all('li')
#     start=time.time()
    all_info=[]
    for item in all_list:
        a_tag=item.find('a')
        title=a_tag['title']
        
        link=a_tag['href']
        item_resp=requests.get("https://comic.naver.com/"+link)
        item_soup=BeautifulSoup(item_resp.content,'html.parser')

        toon_info=item_soup.find('div', class_="webtoon")
        if item_soup.find('div', class_="webtoon").find('ul',class_="category_tab"):
            day=toon_info.find('ul',class_="category_tab").find('li',class_="on").text
        else:                
            day_temp=item_soup.find('table', class_="viewList").find('td',class_="num").text.split('.')
            day_temp[2]='완결'
            day=" ".join(day_temp)

        author_info=toon_info.find('span',class_='wrt_nm')
        author=author_info.text.strip()
        
#         detail_info=toon_info.find('p')
#         detail=detail_info.text.decode('utf-8')

#         all_info.append([title,author,day,detail])
        
        print('{}에 대한 정보를 가져오는 중입니다.'.format(title))
        df=pd.DataFrame({'제목':[title],'작가':[author],'연재상태':[day]})
        if all_list.index(item)==0:
            df.to_csv('all_info.csv', index=False, columns=['제목','작가','연재상태'],encoding='cp949',mode='w')
        else:
            df.to_csv('all_info.csv', index=False, header=False,encoding='cp949',mode='a')

#     df_all_info=pd.DataFrame(all_info, columns=['제목','작가','연재상태','상세설명'])
#         all_info.append([title,author,day])
        
#     df_all_info=pd.DataFrame(all_info, columns=['제목','작가','연재상태'])
#     df_all_info.to_csv('all_info_detail.csv', encoding='cp949')

#         print("Runtime: %0.3f"%(time.time() - start))

# %%
get_naverToon_info()
# Out:
# 가담항설에 대한 정보를 가져오는 중입니다.
# 가비지타임에 대한 정보를 가져오는 중입니다.
# 가우스전자 시즌1~2에 대한 정보를 가져오는 중입니다.
# 가우스전자 시즌3~4에 대한 정보를 가져오는 중입니다.
# 가족사진에 대한 정보를 가져오는 중입니다.
# 간 떨어지는 동거에 대한 정보를 가져오는 중입니다.
# 간질간질에 대한 정보를 가져오는 중입니다.
# 감염자에 대한 정보를 가져오는 중입니다.
# 갓 오브 하이스쿨에 대한 정보를 가져오는 중입니다.
# 갓핑크에 대한 정보를 가져오는 중입니다.
# 강변살다에 대한 정보를 가져오는 중입니다.
# 강시대소동에 대한 정보를 가져오는 중입니다.
# 같은도장에 대한 정보를 가져오는 중입니다.
# 개를 낳았다에 대한 정보를 가져오는 중입니다.
# 개장수에 대한 정보를 가져오는 중입니다.
# 개판에 대한 정보를 가져오는 중입니다.
# 개편 축하 릴레이 카툰에 대한 정보를 가져오는 중입니다.
# 갸오오와 사랑꾼들에 대한 정보를 가져오는 중입니다.
# 거상 김만덕에 대한 정보를 가져오는 중입니다.
# 걸어서 30분에 대한 정보를 가져오는 중입니다.
# 검은인간에 대한 정보를 가져오는 중입니다.
# 겟백에 대한 정보를 가져오는 중입니다.
# 겨울동화에 대한 정보를 가져오는 중입니다.
# 격기3반에 대한 정보를 가져오는 중입니다.
# 격투기특성화사립고교 극지고에 대한 정보를 가져오는 중입니다.
# 견우와 직녀에 대한 정보를 가져오는 중입니다.
# 결계녀에 대한 정보를 가져오는 중입니다.
# 경운기를 탄 왕자님에 대한 정보를 가져오는 중입니다.
# 계룡선녀전에 대한 정보를 가져오는 중입니다.
# 고(故)길창덕화백 추모웹툰에 대한 정보를 가져오는 중입니다.
# 고(故)노무현 前대통령 추모웹툰에 대한 정보를 가져오는 중입니다.
# 고고고에 대한 정보를 가져오는 중입니다.
# 고고루키루에 대한 정보를 가져오는 중입니다.
# 고교생을 환불해 주세요에 대한 정보를 가져오는 중입니다.
# 고류 진에 대한 정보를 가져오는 중입니다.
# 고민툰에 대한 정보를 가져오는 중입니다.
# 고삼무쌍에 대한 정보를 가져오는 중입니다.
# 고삼이 집나갔다에 대한 정보를 가져오는 중입니다.
# 고수에 대한 정보를 가져오는 중입니다.
# 고시생툰에 대한 정보를 가져오는 중입니다.
# 고인돌나라의 야물에 대한 정보를 가져오는 중입니다.
# 고인의 명복에 대한 정보를 가져오는 중입니다.
# 고향의꽃에 대한 정보를 가져오는 중입니다.
# 골든 체인지에 대한 정보를 가져오는 중입니다.
# 골방환상곡에 대한 정보를 가져오는 중입니다.
# 공감.jpg에 대한 정보를 가져오는 중입니다.
# 공대생 너무만화에 대한 정보를 가져오는 중입니다.
# 공복의 저녁식사에 대한 정보를 가져오는 중입니다.
# 공부하기 좋은 날에 대한 정보를 가져오는 중입니다.
# 공주는 잠 못 이루고에 대한 정보를 가져오는 중입니다.
# 괴물신부에 대한 정보를 가져오는 중입니다.
# 교환일기에 대한 정보를 가져오는 중입니다.
# 구구까까에 대한 정보를 가져오는 중입니다.
# 구름의 노래에 대한 정보를 가져오는 중입니다.
# 구름의 이동속도에 대한 정보를 가져오는 중입니다.
# 구름이 피워낸 꽃에 대한 정보를 가져오는 중입니다.
# 구석구석캠페인에 대한 정보를 가져오는 중입니다.
# 국가의 탄생에 대한 정보를 가져오는 중입니다.
# 국립자유경제 고등학교 세실고에 대한 정보를 가져오는 중입니다.
# 국립자유경제고등학교 세실고 2학기에 대한 정보를 가져오는 중입니다.
# 군인RPG에 대한 정보를 가져오는 중입니다.
# 굿모닝 보스에 대한 정보를 가져오는 중입니다.
# 굿모닝 스페이스에 대한 정보를 가져오는 중입니다.
# 권번기생 비밀의 기억에 대한 정보를 가져오는 중입니다.
# 귀각시에 대한 정보를 가져오는 중입니다.
# 귀곡의 문에 대한 정보를 가져오는 중입니다.
# 귀도에 대한 정보를 가져오는 중입니다.
# 귀도호가록에 대한 정보를 가져오는 중입니다.
# 귀인에 대한 정보를 가져오는 중입니다.
# 귀전구담에 대한 정보를 가져오는 중입니다.
# 그 판타지 세계에서 사는 법에 대한 정보를 가져오는 중입니다.
# 그날의 생존자들에 대한 정보를 가져오는 중입니다.
# 그녀는 흡!혈귀에 대한 정보를 가져오는 중입니다.
# 그들에게 사면초가에 대한 정보를 가져오는 중입니다.
# 그래서 나는 안티팬과 결혼했다에 대한 정보를 가져오는 중입니다.
# 그랜드 배틀 토너먼트에 대한 정보를 가져오는 중입니다.
# 그런지에 대한 정보를 가져오는 중입니다.
# 그린보이에 대한 정보를 가져오는 중입니다.
# 그린스마일에 대한 정보를 가져오는 중입니다.
# 극야에 대한 정보를 가져오는 중입니다.
# 금붕어에 대한 정보를 가져오는 중입니다.
# 금수저에 대한 정보를 가져오는 중입니다.
# 금요일 베스트에 대한 정보를 가져오는 중입니다.
# 기기괴괴에 대한 정보를 가져오는 중입니다.
# 기로에 대한 정보를 가져오는 중입니다.
# 기사도에 대한 정보를 가져오는 중입니다.
# 기적! 우리에게 일어난 일들에 대한 정보를 가져오는 중입니다.
# 기타맨에 대한 정보를 가져오는 중입니다.
# 기태류에 대한 정보를 가져오는 중입니다.
# 길에서 만나다에 대한 정보를 가져오는 중입니다.
# 까뱅에 대한 정보를 가져오는 중입니다.
# 까치우는 날에 대한 정보를 가져오는 중입니다.
# 꼬리에 대한 정보를 가져오는 중입니다.
# 꽃 피는 날에 대한 정보를 가져오는 중입니다.
# 꽃가족에 대한 정보를 가져오는 중입니다.
# 꽃미남 저승사자에 대한 정보를 가져오는 중입니다.
# 꽃밭에솔에 대한 정보를 가져오는 중입니다.
# 꿀벌과 아카시아에 대한 정보를 가져오는 중입니다.
# 꿈의 기업에 대한 정보를 가져오는 중입니다.
# 나노리스트에 대한 정보를 가져오는 중입니다.
# 나는 귀머거리다에 대한 정보를 가져오는 중입니다.
# 나는 남 너는 녀에 대한 정보를 가져오는 중입니다.
# 나는 너를 보았다에 대한 정보를 가져오는 중입니다.
# 나는 어디에 있는 거니에 대한 정보를 가져오는 중입니다.
# 나란의사 그런의사에 대한 정보를 가져오는 중입니다.
# 나의 목소리를 들어라에 대한 정보를 가져오는 중입니다.
# 나의 짝사랑 고백법에 대한 정보를 가져오는 중입니다.
# 나이트런에 대한 정보를 가져오는 중입니다.
# 낚시신공에 대한 정보를 가져오는 중입니다.
# 날 가져요에 대한 정보를 가져오는 중입니다.
# 날로 먹는 연애에 대한 정보를 가져오는 중입니다.
# 낢 부럽지 않은 신혼여행기에 대한 정보를 가져오는 중입니다.
# 낢에게와요에 대한 정보를 가져오는 중입니다.
# 낢이사는이야기에 대한 정보를 가져오는 중입니다.
# 남과 여에 대한 정보를 가져오는 중입니다.
# 남기한엘리트만들기에 대한 정보를 가져오는 중입니다.
# 낮에 뜨는 달에 대한 정보를 가져오는 중입니다.
# 내 ID는 강남미인!에 대한 정보를 가져오는 중입니다.
# 내 ID는 강남미인! - 둘만의 시간에 대한 정보를 가져오는 중입니다.
# 내 어린고양이와 늙은개 (재)에 대한 정보를 가져오는 중입니다.
# 내 여자친구는 상남자에 대한 정보를 가져오는 중입니다.
# 내가 결혼할 때까지에 대한 정보를 가져오는 중입니다.
# 내일에 대한 정보를 가져오는 중입니다.
# 내일은 럭키곰스타에 대한 정보를 가져오는 중입니다.
# 내일은 웹툰에 대한 정보를 가져오는 중입니다.
# 냐한남자에 대한 정보를 가져오는 중입니다.
# 냥하무인에 대한 정보를 가져오는 중입니다.
# 너와 너 사이에 대한 정보를 가져오는 중입니다.
# 네가 없는 세상에 대한 정보를 가져오는 중입니다.
# 네로의 실험실에 대한 정보를 가져오는 중입니다.
# 네버랜 연대기에 대한 정보를 가져오는 중입니다.
# 네이버 앱피소드에 대한 정보를 가져오는 중입니다.
# 노곤하개에 대한 정보를 가져오는 중입니다.
# 노네임드(NoNameD)에 대한 정보를 가져오는 중입니다.
# 노블레스에 대한 정보를 가져오는 중입니다.
# 녹두전에 대한 정보를 가져오는 중입니다.
# 놓정동화에 대한 정보를 가져오는 중입니다.
# 놓지마 정신줄에 대한 정보를 가져오는 중입니다.
# 놓지마 정신줄 시즌2에 대한 정보를 가져오는 중입니다.
# 늑대와 빨간모자에 대한 정보를 가져오는 중입니다.
# 늘 푸른 찻집에 대한 정보를 가져오는 중입니다.
# 니편내편에 대한 정보를 가져오는 중입니다.
# 다욤이의 다이어트 다이어리에 대한 정보를 가져오는 중입니다.
# 다이스(DICE)에 대한 정보를 가져오는 중입니다.
# 닥터 프로스트에 대한 정보를 가져오는 중입니다.
# 닥터 프로스트 시즌3에 대한 정보를 가져오는 중입니다.
# 닥터 하운드에 대한 정보를 가져오는 중입니다.
# 단군할배요에 대한 정보를 가져오는 중입니다.
# 단편 할머니/나는내일죽는다에 대한 정보를 가져오는 중입니다.
# 달수 이야기에 대한 정보를 가져오는 중입니다.
# 달콤한 인생에 대한 정보를 가져오는 중입니다.
# 달콤한 인생_스페셜 에피소드에 대한 정보를 가져오는 중입니다.
# 닭통령 계양반에 대한 정보를 가져오는 중입니다.
# 당신만 몰라!에 대한 정보를 가져오는 중입니다.
# 대작에 대한 정보를 가져오는 중입니다.
# 대표님이 구독하셨습니다에 대한 정보를 가져오는 중입니다.
# 대학일기에 대한 정보를 가져오는 중입니다.
# 더 게이머에 대한 정보를 가져오는 중입니다.
# 데드데이즈(DEAD DAYS)에 대한 정보를 가져오는 중입니다.
# 데드라이프에 대한 정보를 가져오는 중입니다.
# 데모니악에 대한 정보를 가져오는 중입니다.
# 데우스 엑스 마키나에 대한 정보를 가져오는 중입니다.
# 덴마에 대한 정보를 가져오는 중입니다.
# 도망자에 대한 정보를 가져오는 중입니다.
# 도자기에 대한 정보를 가져오는 중입니다.
# 독신으로 살겠다에 대한 정보를 가져오는 중입니다.
# 돌아온 럭키짱에 대한 정보를 가져오는 중입니다.
# 동경소녀에 대한 정보를 가져오는 중입니다.
# 동네변호사 조들호 시즌1에 대한 정보를 가져오는 중입니다.
# 동네변호사 조들호 시즌2에 대한 정보를 가져오는 중입니다.
# 동토의 여명에 대한 정보를 가져오는 중입니다.
# 돼지만화에 대한 정보를 가져오는 중입니다.
# 돼지우리에 대한 정보를 가져오는 중입니다.
# 두근거려요에 대한 정보를 가져오는 중입니다.
# 두근두근 마감 중에 대한 정보를 가져오는 중입니다.
# 두근두근두근거려에 대한 정보를 가져오는 중입니다.
# 둥굴레차!에 대한 정보를 가져오는 중입니다.
# 드래곤레시피에 대한 정보를 가져오는 중입니다.
# 딥(DEEP)에 대한 정보를 가져오는 중입니다.
# 땅 보고 걷는 아이에 대한 정보를 가져오는 중입니다.
# 뜨거운 것이 좋아.에 대한 정보를 가져오는 중입니다.
# 라스트 서브미션에 대한 정보를 가져오는 중입니다.
# 라이징패스트볼에 대한 정보를 가져오는 중입니다.
# 라크리모사에 대한 정보를 가져오는 중입니다.
# 랜덤채팅의 그녀!에 대한 정보를 가져오는 중입니다.
# 러브슬립에 대한 정보를 가져오는 중입니다.
# 러브슬립 2부에 대한 정보를 가져오는 중입니다.
# 러브판타지페이퍼에 대한 정보를 가져오는 중입니다.
# 레드돌에 대한 정보를 가져오는 중입니다.
# 레드초콜릿에 대한 정보를 가져오는 중입니다.
# 레드카펫에 대한 정보를 가져오는 중입니다.
# 레사 시즌2~3에 대한 정보를 가져오는 중입니다.
# 레사(lessa)에 대한 정보를 가져오는 중입니다.
# 레인보우 로즈에 대한 정보를 가져오는 중입니다.
# 레코닝에 대한 정보를 가져오는 중입니다.
# 로베스의 완전감각에 대한 정보를 가져오는 중입니다.
# 로봇빠찌에 대한 정보를 가져오는 중입니다.
# 롤랑롤랑에 대한 정보를 가져오는 중입니다.
# 리버스에 대한 정보를 가져오는 중입니다.
# 리얼주주에 대한 정보를 가져오는 중입니다.
# 리즌에 대한 정보를 가져오는 중입니다.
# 리턴에 대한 정보를 가져오는 중입니다.
# 링크보이에 대한 정보를 가져오는 중입니다.
# 마녀사냥에 대한 정보를 가져오는 중입니다.
# 마루한 - 구현동화전에 대한 정보를 가져오는 중입니다.
# 마법스크롤 상인 지오에 대한 정보를 가져오는 중입니다.
# 마술사에 대한 정보를 가져오는 중입니다.
# 마스크걸에 대한 정보를 가져오는 중입니다.
# 마야고에 대한 정보를 가져오는 중입니다.
# 마왕이 되는 중2야에 대한 정보를 가져오는 중입니다.
# 마음의 숙제에 대한 정보를 가져오는 중입니다.
# 마음의소리에 대한 정보를 가져오는 중입니다.
# 마이너스의 손에 대한 정보를 가져오는 중입니다.
# 마주쳤다에 대한 정보를 가져오는 중입니다.
# 만 화 고에 대한 정보를 가져오는 중입니다.
# 만렙소녀 오오라에 대한 정보를 가져오는 중입니다.
# 만화사랑 캠페인에 대한 정보를 가져오는 중입니다.
# 맘마미안에 대한 정보를 가져오는 중입니다.
# 맛집남녀에 대한 정보를 가져오는 중입니다.
# 매지컬 고삼즈에 대한 정보를 가져오는 중입니다.
# 머니게임에 대한 정보를 가져오는 중입니다.
# 머리카락을 뽑으면에 대한 정보를 가져오는 중입니다.
# 먹이에 대한 정보를 가져오는 중입니다.
# 멍순이에 대한 정보를 가져오는 중입니다.
# 멜로홀릭에 대한 정보를 가져오는 중입니다.
# 모던패밀리에 대한 정보를 가져오는 중입니다.
# 모던패밀리 2에 대한 정보를 가져오는 중입니다.
# 모두에게 완자가에 대한 정보를 가져오는 중입니다.
# 모디파이에 대한 정보를 가져오는 중입니다.
# 모죠의 일지에 대한 정보를 가져오는 중입니다.
# 모태솔로수용소에 대한 정보를 가져오는 중입니다.
# 모태솔로수용소 시즌2~3에 대한 정보를 가져오는 중입니다.
# 모퉁이 뜨개방에 대한 정보를 가져오는 중입니다.
# 목욕의 신 (재)에 대한 정보를 가져오는 중입니다.
# 몽연에 대한 정보를 가져오는 중입니다.
# 몽타주에 대한 정보를 가져오는 중입니다.
# 몽홀에 대한 정보를 가져오는 중입니다.
# 무모협지에 대한 정보를 가져오는 중입니다.
# 무주의 맹시에 대한 정보를 가져오는 중입니다.
# 무한도전 릴레이툰에 대한 정보를 가져오는 중입니다.
# 무한동력에 대한 정보를 가져오는 중입니다.
# 묵회에 대한 정보를 가져오는 중입니다.
# 문래빗에 대한 정보를 가져오는 중입니다.
# 문아에 대한 정보를 가져오는 중입니다.
# 문유에 대한 정보를 가져오는 중입니다.
# 므시미르에 대한 정보를 가져오는 중입니다.
# 미결에 대한 정보를 가져오는 중입니다.
# 미드나잇 체이서에 대한 정보를 가져오는 중입니다.
# 미라클! 용사님에 대한 정보를 가져오는 중입니다.
# 미래소녀에 대한 정보를 가져오는 중입니다.
# 미선 임파서블에 대한 정보를 가져오는 중입니다.
# 미숙한 친구는 G구인에 대한 정보를 가져오는 중입니다.
# 미스터리 호러 지하철 (재)에 대한 정보를 가져오는 중입니다.
# 미시령에 대한 정보를 가져오는 중입니다.
# 미쳐 날뛰는 생활툰에 대한 정보를 가져오는 중입니다.
# 미호이야기에 대한 정보를 가져오는 중입니다.
# 바나나걸에 대한 정보를 가져오는 중입니다.
# 바람의 색에 대한 정보를 가져오는 중입니다.
# 바람이 머무는 난에 대한 정보를 가져오는 중입니다.
# 바로잡는 순애보에 대한 정보를 가져오는 중입니다.
# 바른연애 길잡이에 대한 정보를 가져오는 중입니다.
# 바이올린처럼.에 대한 정보를 가져오는 중입니다.
# 반월에 대한 정보를 가져오는 중입니다.
# 반지의제왕에 대한 정보를 가져오는 중입니다.
# 반투명인간에 대한 정보를 가져오는 중입니다.
# 밥 먹고 갈래요?에 대한 정보를 가져오는 중입니다.
# 밥풀때기에 대한 정보를 가져오는 중입니다.
# 방 안의 코끼리에 대한 정보를 가져오는 중입니다.
# 방과 후 전쟁활동에 대한 정보를 가져오는 중입니다.
# 방백남녀에 대한 정보를 가져오는 중입니다.
# 방울토마토에 대한 정보를 가져오는 중입니다.
# 백귀야행지에 대한 정보를 가져오는 중입니다.
# 뱀이 앉은 자리에 대한 정보를 가져오는 중입니다.
# 뱀파이어에 대한 정보를 가져오는 중입니다.
# 뱀파이어의 꽃에 대한 정보를 가져오는 중입니다.
# 뱀피르에 대한 정보를 가져오는 중입니다.
# 버그에 대한 정보를 가져오는 중입니다.
# 버닝헬에 대한 정보를 가져오는 중입니다.
# 버퍼링에 대한 정보를 가져오는 중입니다.
# 버프소녀 오오라에 대한 정보를 가져오는 중입니다.
# 번개기동대 2009에 대한 정보를 가져오는 중입니다.
# 번데기스에 대한 정보를 가져오는 중입니다.
# 별의 유언에 대한 정보를 가져오는 중입니다.
# 병의 기록에 대한 정보를 가져오는 중입니다.
# 병의 맛에 대한 정보를 가져오는 중입니다.
# 보톡스에 대한 정보를 가져오는 중입니다.
# 복학왕에 대한 정보를 가져오는 중입니다.
# 봄이여 오라에 대한 정보를 가져오는 중입니다.
# 봉봉오쇼콜라에 대한 정보를 가져오는 중입니다.
# 부로콜리왕자에 대한 정보를 가져오는 중입니다.
# 부부생활에 대한 정보를 가져오는 중입니다.
# 부토에 대한 정보를 가져오는 중입니다.
# 부활남에 대한 정보를 가져오는 중입니다.
# 불괴에 대한 정보를 가져오는 중입니다.
# 불량 뱀파이어에 대한 정보를 가져오는 중입니다.
# 불만시대에 대한 정보를 가져오는 중입니다.
# 붉은 실에 대한 정보를 가져오는 중입니다.
# 뷰티풀 군바리에 대한 정보를 가져오는 중입니다.
# 뷰티플 게임에 대한 정보를 가져오는 중입니다.
# 블라인드에 대한 정보를 가져오는 중입니다.
# 블라인드 메르헨에 대한 정보를 가져오는 중입니다.
# 블랙수트에 대한 정보를 가져오는 중입니다.
# 블랙시저스에 대한 정보를 가져오는 중입니다.
# 블랙엔젤에 대한 정보를 가져오는 중입니다.
# 비둘기가 물고 온 남자에 대한 정보를 가져오는 중입니다.
# 비바 산티아고에 대한 정보를 가져오는 중입니다.
# 비질란테에 대한 정보를 가져오는 중입니다.
# 비흔에 대한 정보를 가져오는 중입니다.
# 빙의에 대한 정보를 가져오는 중입니다.
# 빙탕후루에 대한 정보를 가져오는 중입니다.
# 빨간책에 대한 정보를 가져오는 중입니다.
# 빵점동맹에 대한 정보를 가져오는 중입니다.
# 사냥개들에 대한 정보를 가져오는 중입니다.
# 사노라면에 대한 정보를 가져오는 중입니다.
# 사또(Satto)에 대한 정보를 가져오는 중입니다.
# 사라지다에 대한 정보를 가져오는 중입니다.
# 사랑in에 대한 정보를 가져오는 중입니다.
# 사랑을 연기하다에 대한 정보를 가져오는 중입니다.
# 사랑의 아쿠아리움에 대한 정보를 가져오는 중입니다.
# 사랑의 외계인에 대한 정보를 가져오는 중입니다.
# 사랑일까?에 대한 정보를 가져오는 중입니다.
# 사우러스에 대한 정보를 가져오는 중입니다.
# 사이드킥에 대한 정보를 가져오는 중입니다.
# 사이드킥 2~3에 대한 정보를 가져오는 중입니다.
# 살人스타그램에 대한 정보를 가져오는 중입니다.
# 살인자o난감 (재)에 대한 정보를 가져오는 중입니다.
# 삵의 발톱에 대한 정보를 가져오는 중입니다.
# 삶이 우리를 속일지라도에 대한 정보를 가져오는 중입니다.
# 삼국전투기에 대한 정보를 가져오는 중입니다.
# 삼국지톡에 대한 정보를 가져오는 중입니다.
# 삼봉이발소에 대한 정보를 가져오는 중입니다.
# 상중하에 대한 정보를 가져오는 중입니다.
# 새끼손가락에 대한 정보를 가져오는 중입니다.
# 새벽9시에 대한 정보를 가져오는 중입니다.
# 새와 같이에 대한 정보를 가져오는 중입니다.
# 색으로 말하다에 대한 정보를 가져오는 중입니다.
# 샌프란시스코 화랑관에 대한 정보를 가져오는 중입니다.
# 생활의참견에 대한 정보를 가져오는 중입니다.
# 섀도우에 대한 정보를 가져오는 중입니다.
# 서북의 저승사자에 대한 정보를 가져오는 중입니다.
# 선천적 얼간이들 (재)에 대한 정보를 가져오는 중입니다.
# 성공한 덕후에 대한 정보를 가져오는 중입니다.
# 세개의시간에 대한 정보를 가져오는 중입니다.
# 세상은 돈과 권력에 대한 정보를 가져오는 중입니다.
# 소곤소곤에 대한 정보를 가져오는 중입니다.
# 소나기야에 대한 정보를 가져오는 중입니다.
# 소녀 연대기에 대한 정보를 가져오는 중입니다.
# 소녀더와일즈에 대한 정보를 가져오는 중입니다.
# 소녀의 세계에 대한 정보를 가져오는 중입니다.
# 소년들은 무엇을 하고 있을까에 대한 정보를 가져오는 중입니다.
# 소년전[Limit]에 대한 정보를 가져오는 중입니다.
# 소설가J에 대한 정보를 가져오는 중입니다.
# 소울카르텔에 대한 정보를 가져오는 중입니다.
# 소유에 대한 정보를 가져오는 중입니다.
# 속삭이는 e로맨스에 대한 정보를 가져오는 중입니다.
# 손의 흔적에 대한 정보를 가져오는 중입니다.
# 송곳 1~3부에 대한 정보를 가져오는 중입니다.
# 송곳 4~5부에 대한 정보를 가져오는 중입니다.
# 수사9단에 대한 정보를 가져오는 중입니다.
# 수업시간그녀에 대한 정보를 가져오는 중입니다.
# 수학 잘하는 법에 대한 정보를 가져오는 중입니다.
# 숨:킬더바디에 대한 정보를 가져오는 중입니다.
# 숲 속의 미마에 대한 정보를 가져오는 중입니다.
# 슈퍼 시크릿에 대한 정보를 가져오는 중입니다.
# 슈퍼트리오에 대한 정보를 가져오는 중입니다.
# 슈퍼트리오 시즌2에 대한 정보를 가져오는 중입니다.
# 스마일 브러시, 오래된 사진.에 대한 정보를 가져오는 중입니다.
# 스마일브러시에 대한 정보를 가져오는 중입니다.
# 스마트폰 게임 개발 이야기에 대한 정보를 가져오는 중입니다.
# 스위트홈에 대한 정보를 가져오는 중입니다.
# 스쿨홀릭에 대한 정보를 가져오는 중입니다.
# 스터디그룹에 대한 정보를 가져오는 중입니다.
# 스토커에 대한 정보를 가져오는 중입니다.
# 스튜디오 짭쪼롬에 대한 정보를 가져오는 중입니다.
# 스퍼맨에 대한 정보를 가져오는 중입니다.
# 스페이스 차이나드레스에 대한 정보를 가져오는 중입니다.
# 스페이스 킹에 대한 정보를 가져오는 중입니다.
# 스펙트럼 분석기에 대한 정보를 가져오는 중입니다.
# 스피릿 핑거스에 대한 정보를 가져오는 중입니다.
# 시간의 섬에 대한 정보를 가져오는 중입니다.
# 시노딕에 대한 정보를 가져오는 중입니다.
# 시큼새큼에 대한 정보를 가져오는 중입니다.
# 시타를 위하여에 대한 정보를 가져오는 중입니다.
# 식스센스에 대한 정보를 가져오는 중입니다.
# 식스틴에 대한 정보를 가져오는 중입니다.
# 신과함께 (재)에 대한 정보를 가져오는 중입니다.
# 신도림에 대한 정보를 가져오는 중입니다.
# 신령에 대한 정보를 가져오는 중입니다.
# 신석기녀에 대한 정보를 가져오는 중입니다.
# 신시의 손님에 대한 정보를 가져오는 중입니다.
# 신암행어사에 대한 정보를 가져오는 중입니다.
# 신을 죽이는 방법에 대한 정보를 가져오는 중입니다.
# 신의 언어에 대한 정보를 가져오는 중입니다.
# 신의 탑에 대한 정보를 가져오는 중입니다.
# 실질객관동화에 대한 정보를 가져오는 중입니다.
# 실질객관영화에 대한 정보를 가져오는 중입니다.
# 심부름센터 K에 대한 정보를 가져오는 중입니다.
# 심심한 마왕에 대한 정보를 가져오는 중입니다.
# 심연의 하늘 시즌 1~3에 대한 정보를 가져오는 중입니다.
# 심연의 하늘 시즌4에 대한 정보를 가져오는 중입니다.
# 심연의 하늘 시즌5에 대한 정보를 가져오는 중입니다.
# 심장이뛰다에 대한 정보를 가져오는 중입니다.
# 싸귀2 : 퇴마록에 대한 정보를 가져오는 중입니다.
# 싸우자귀신아에 대한 정보를 가져오는 중입니다.
# 쌉니다 천리마마트 (재)에 대한 정보를 가져오는 중입니다.
# 썸남에 대한 정보를 가져오는 중입니다.
# 쎈놈에 대한 정보를 가져오는 중입니다.
# 쎈놈 외전에 대한 정보를 가져오는 중입니다.
# 씬커에 대한 정보를 가져오는 중입니다.
# 아기낳는만화에 대한 정보를 가져오는 중입니다.
# 아는사람 이야기에 대한 정보를 가져오는 중입니다.
# 아도나이에 대한 정보를 가져오는 중입니다.
# 아랫집 시누이에 대한 정보를 가져오는 중입니다.
# 아르마에 대한 정보를 가져오는 중입니다.
# 아메리카노 엑소더스에 대한 정보를 가져오는 중입니다.
# 아부쟁이에 대한 정보를 가져오는 중입니다.
# 아빠를 찾습니다에 대한 정보를 가져오는 중입니다.
# 아스란영웅전에 대한 정보를 가져오는 중입니다.
# 아이덴티티에 대한 정보를 가져오는 중입니다.
# 아이돌 연구소에 대한 정보를 가져오는 중입니다.
# 아이들은 즐겁다에 대한 정보를 가져오는 중입니다.
# 아이들의 권 선생님에 대한 정보를 가져오는 중입니다.
# 아이소포스 1, 2부에 대한 정보를 가져오는 중입니다.
# 아이소포스 3부에 대한 정보를 가져오는 중입니다.
# 아일랜드 1부에 대한 정보를 가져오는 중입니다.
# 아일랜드 2부에 대한 정보를 가져오는 중입니다.
# 아테나 컴플렉스에 대한 정보를 가져오는 중입니다.
# 아프니까 병원이다에 대한 정보를 가져오는 중입니다.
# 아홉수 우리들에 대한 정보를 가져오는 중입니다.
# 악당의 사연에 대한 정보를 가져오는 중입니다.
# 악마와 계약연애에 대한 정보를 가져오는 중입니다.
# 악연에 대한 정보를 가져오는 중입니다.
# 악의는 없다에 대한 정보를 가져오는 중입니다.
# 악플게임에 대한 정보를 가져오는 중입니다.
# 안 돼요 마왕님!에 대한 정보를 가져오는 중입니다.
# 안나라수마나라에 대한 정보를 가져오는 중입니다.
# 안녕, 대학생에 대한 정보를 가져오는 중입니다.
# 알게뭐야에 대한 정보를 가져오는 중입니다.
# 알고있지만에 대한 정보를 가져오는 중입니다.
# 알파에 대한 정보를 가져오는 중입니다.
# 암흑도시에 대한 정보를 가져오는 중입니다.
# 야! 오이에 대한 정보를 가져오는 중입니다.
# 야부리맨에 대한 정보를 가져오는 중입니다.
# 야채호빵의 봄방학에 대한 정보를 가져오는 중입니다.
# 약한영웅에 대한 정보를 가져오는 중입니다.
# 어글리후드에 대한 정보를 가져오는 중입니다.
# 어빌리티에 대한 정보를 가져오는 중입니다.
# 어서오세요.305호에에 대한 정보를 가져오는 중입니다.
# 언더클래스 히어로에 대한 정보를 가져오는 중입니다.
# 언더프린에 대한 정보를 가져오는 중입니다.
# 언덕 위의 제임스에 대한 정보를 가져오는 중입니다.
# 언데드에 대한 정보를 가져오는 중입니다.
# 언원티드에 대한 정보를 가져오는 중입니다.
# 언터처블에 대한 정보를 가져오는 중입니다.
# 얼룩말에 대한 정보를 가져오는 중입니다.
# 엄마와 딸 x2에 대한 정보를 가져오는 중입니다.
# 에이머에 대한 정보를 가져오는 중입니다.
# 에이틴에 대한 정보를 가져오는 중입니다.
# 에피소드메이비에 대한 정보를 가져오는 중입니다.
# 에피소드칵테일에 대한 정보를 가져오는 중입니다.
# 엔드리스에 대한 정보를 가져오는 중입니다.
# 여기가 씨름부입니까?에 대한 정보를 가져오는 중입니다.
# 여신강림에 대한 정보를 가져오는 중입니다.
# 여중생A에 대한 정보를 가져오는 중입니다.
# 여중생A-우리들의 축제에 대한 정보를 가져오는 중입니다.
# 여탕보고서에 대한 정보를 가져오는 중입니다.
# 역전! 야매요리에 대한 정보를 가져오는 중입니다.
# 연에 대한 정보를 가져오는 중입니다.
# 연 시즌2에 대한 정보를 가져오는 중입니다.
# 연놈에 대한 정보를 가져오는 중입니다.
# 연애세포에 대한 정보를 가져오는 중입니다.
# 연애의 정령에 대한 정보를 가져오는 중입니다.
# 연애학에 대한 정보를 가져오는 중입니다.
# 연애혁명에 대한 정보를 가져오는 중입니다.
# 연옥님이 보고계셔에 대한 정보를 가져오는 중입니다.
# 연의 편지에 대한 정보를 가져오는 중입니다.
# 열대어에 대한 정보를 가져오는 중입니다.
# 열렙전사에 대한 정보를 가져오는 중입니다.
# 열무가 익어간다에 대한 정보를 가져오는 중입니다.
# 열불 로맨스에 대한 정보를 가져오는 중입니다.
# 열쇠줍는아이에 대한 정보를 가져오는 중입니다.
# 열아홉스물하나에 대한 정보를 가져오는 중입니다.
# 열일곱에 대한 정보를 가져오는 중입니다.
# 열정호구에 대한 정보를 가져오는 중입니다.
# 영수의 봄에 대한 정보를 가져오는 중입니다.
# 영웅열공전에 대한 정보를 가져오는 중입니다.
# 옆반의 인어에 대한 정보를 가져오는 중입니다.
# 옆집친구에 대한 정보를 가져오는 중입니다.
# 옆집화랑에 대한 정보를 가져오는 중입니다.
# 오!주예수여에 대한 정보를 가져오는 중입니다.
# 오늘 밤은 어둠이 무서워요에 대한 정보를 가져오는 중입니다.
# 오늘도 사랑스럽개에 대한 정보를 가져오는 중입니다.
# 오늘도 핸드메이드!에 대한 정보를 가져오는 중입니다.
# 오늘도 형제는 평화롭다에 대한 정보를 가져오는 중입니다.
# 오늘부터 주군에 대한 정보를 가져오는 중입니다.
# 오늘의 낭만부에 대한 정보를 가져오는 중입니다.
# 오늘의 순정망화에 대한 정보를 가져오는 중입니다.
# 오라존미에 대한 정보를 가져오는 중입니다.
# 오란씨100에 대한 정보를 가져오는 중입니다.
# 오렌지 마말레이드에 대한 정보를 가져오는 중입니다.
# 오민혁 단편선에 대한 정보를 가져오는 중입니다.
# 오빠 왔다에 대한 정보를 가져오는 중입니다.
# 오성X한음에 대한 정보를 가져오는 중입니다.
# 오일머니에 대한 정보를 가져오는 중입니다.
# 오즈랜드에 대한 정보를 가져오는 중입니다.
# 오직 나의 주인님에 대한 정보를 가져오는 중입니다.
# 올해의 벚꽃도 함께에 대한 정보를 가져오는 중입니다.
# 와라! 편의점에 대한 정보를 가져오는 중입니다.
# 와라편의점 the animation에 대한 정보를 가져오는 중입니다.
# 와일드와일드워커스에 대한 정보를 가져오는 중입니다.
# 와장창창! 자취맨에 대한 정보를 가져오는 중입니다.
# 와탕카에 대한 정보를 가져오는 중입니다.
# 와탕카2에 대한 정보를 가져오는 중입니다.
# 완벽하지 않은 키스에 대한 정보를 가져오는 중입니다.
# 완벽한 허니문에 대한 정보를 가져오는 중입니다.
# 왕으로 살다에 대한 정보를 가져오는 중입니다.
# 외모지상주의에 대한 정보를 가져오는 중입니다.
# 요괴대전에 대한 정보를 가져오는 중입니다.
# 요리GO에 대한 정보를 가져오는 중입니다.
# 요리대마왕에 대한 정보를 가져오는 중입니다.
# 용비불패 완전판에 대한 정보를 가져오는 중입니다.
# 용이산다에 대한 정보를 가져오는 중입니다.
# 우렁집사에 대한 정보를 가져오는 중입니다.
# 우리 오빠는 아이돌에 대한 정보를 가져오는 중입니다.
# 우리 헤어졌어요에 대한 정보를 가져오는 중입니다.
# 우리들은 푸르다에 대한 정보를 가져오는 중입니다.
# 우리의 이상한 여행에 대한 정보를 가져오는 중입니다.
# 우리집에 곰이 이사왔다에 대한 정보를 가져오는 중입니다.
# 우바우에 대한 정보를 가져오는 중입니다.
# 우연일까?에 대한 정보를 가져오는 중입니다.
# 우월한하루에 대한 정보를 가져오는 중입니다.
# 우주전함 몰라몰라에 대한 정보를 가져오는 중입니다.
# 우주최강대스타에 대한 정보를 가져오는 중입니다.
# 운빨로맨스에 대한 정보를 가져오는 중입니다.
# 움비처럼에 대한 정보를 가져오는 중입니다.
# 웃지 않는 개그반 시즌1~2에 대한 정보를 가져오는 중입니다.
# 웃지 않는 개그반 시즌3에 대한 정보를 가져오는 중입니다.
# 웅이는 배고파에 대한 정보를 가져오는 중입니다.
# 원 뿔러스 원에 대한 정보를 가져오는 중입니다.
# 원미동 백수에 대한 정보를 가져오는 중입니다.
# 원주민 공포만화에 대한 정보를 가져오는 중입니다.
# 원티드에 대한 정보를 가져오는 중입니다.
# 월남특급에 대한 정보를 가져오는 중입니다.
# 웨스트우드 비브라토에 대한 정보를 가져오는 중입니다.
# 위대한 방옥숙에 대한 정보를 가져오는 중입니다.
# 위아더 능력자!에 대한 정보를 가져오는 중입니다.
# 위장불륜 (僞裝不倫)에 대한 정보를 가져오는 중입니다.
# 윈드브레이커에 대한 정보를 가져오는 중입니다.
# 윈터우즈에 대한 정보를 가져오는 중입니다.
# 윌유메리미에 대한 정보를 가져오는 중입니다.
# 유미의 세포들에 대한 정보를 가져오는 중입니다.
# 유일무이 로맨스에 대한 정보를 가져오는 중입니다.
# 유토피아에 대한 정보를 가져오는 중입니다.
# 은주의 방에 대한 정보를 가져오는 중입니다.
# 은주의 방 2~3부에 대한 정보를 가져오는 중입니다.
# 은하연인전에 대한 정보를 가져오는 중입니다.
# 의령수에 대한 정보를 가져오는 중입니다.
# 이것도 친구라고에 대한 정보를 가져오는 중입니다.
# 이계 무슨 황비에 대한 정보를 가져오는 중입니다.
# 이기자, 그린에 대한 정보를 가져오는 중입니다.
# 이런 영웅은 싫어에 대한 정보를 가져오는 중입니다.
# 이말년 서유기에 대한 정보를 가져오는 중입니다.
# 이말년씨리즈에 대한 정보를 가져오는 중입니다.
# 이말년씨리즈 2018에 대한 정보를 가져오는 중입니다.
# 이별만화 완성도에 대한 정보를 가져오는 중입니다.
# 이상하고 아름다운에 대한 정보를 가져오는 중입니다.
# 이제 곧 죽습니다에 대한 정보를 가져오는 중입니다.
# 이츠마인에 대한 정보를 가져오는 중입니다.
# 이현세, 이두호의 지옥캠프 단편선에 대한 정보를 가져오는 중입니다.
# 인간의 숲 (재)에 대한 정보를 가져오는 중입니다.
# 인어를 위한 수영교실에 대한 정보를 가져오는 중입니다.
# 인챈트-나람이야기에 대한 정보를 가져오는 중입니다.
# 인형의 기사에 대한 정보를 가져오는 중입니다.
# 일등당첨에 대한 정보를 가져오는 중입니다.
# 일렉시드에 대한 정보를 가져오는 중입니다.
# 일사부재리에 대한 정보를 가져오는 중입니다.
# 일상날개짓에 대한 정보를 가져오는 중입니다.
# 일진에게 회초리에 대한 정보를 가져오는 중입니다.
# 일진이 사나워에 대한 정보를 가져오는 중입니다.
# 일편단심화에 대한 정보를 가져오는 중입니다.
# 입시명문사립 정글고등학교에 대한 정보를 가져오는 중입니다.
# 잉잉잉에 대한 정보를 가져오는 중입니다.
# 자율공상축구탐구만화에 대한 정보를 가져오는 중입니다.
# 자취로운 생활에 대한 정보를 가져오는 중입니다.
# 자판귀에 대한 정보를 가져오는 중입니다.
# 잡다한컷에 대한 정보를 가져오는 중입니다.
# 장미아파트 공경비에 대한 정보를 가져오는 중입니다.
# 장씨세가 호위무사에 대한 정보를 가져오는 중입니다.
# 재앙은 미묘하게에 대한 정보를 가져오는 중입니다.
# 저승에서 만난 사람들에 대한 정보를 가져오는 중입니다.
# 적생에 대한 정보를 가져오는 중입니다.
# 전설의 레전드에 대한 정보를 가져오는 중입니다.
# 전자오락수호대에 대한 정보를 가져오는 중입니다.
# 절벽귀 (재)에 대한 정보를 가져오는 중입니다.
# 점핑오버에 대한 정보를 가져오는 중입니다.
# 정년이에 대한 정보를 가져오는 중입니다.
# 제로에 대한 정보를 가져오는 중입니다.
# 제로게임에 대한 정보를 가져오는 중입니다.
# 제주구슬할망에 대한 정보를 가져오는 중입니다.
# 제페토에 대한 정보를 가져오는 중입니다.
# 조석축구만화에 대한 정보를 가져오는 중입니다.
# 조선왕조실톡에 대한 정보를 가져오는 중입니다.
# 조선좀비실록에 대한 정보를 가져오는 중입니다.
# 조선팔도 최강아이돌에 대한 정보를 가져오는 중입니다.
# 조의 영역에 대한 정보를 가져오는 중입니다.
# 좀비딸에 대한 정보를 가져오는 중입니다.
# 좀비를 위한 나라는 없다에 대한 정보를 가져오는 중입니다.
# 좋아하는 부분에 대한 정보를 가져오는 중입니다.
# 죄의 파편에 대한 정보를 가져오는 중입니다.
# 죽은 마법사의 도시에 대한 정보를 가져오는 중입니다.
# 죽음에 관하여 (재)에 대한 정보를 가져오는 중입니다.
# 중립디자인구역에 대한 정보를 가져오는 중입니다.
# 증거에 대한 정보를 가져오는 중입니다.
# 지금 우리 학교는에 대한 정보를 가져오는 중입니다.
# 지금 이 순간 마법처럼에 대한 정보를 가져오는 중입니다.
# 지상 최악의 소년에 대한 정보를 가져오는 중입니다.
# 지새는 달에 대한 정보를 가져오는 중입니다.
# 지옥캠프 단편선 시즌2에 대한 정보를 가져오는 중입니다.
# 지옥캠프 단편선 시즌3에 대한 정보를 가져오는 중입니다.
# 지옥캠프 단편선 시즌4에 대한 정보를 가져오는 중입니다.
# 지옥캠프 단편선 시즌5에 대한 정보를 가져오는 중입니다.
# 지옥캠프 단편선 시즌6에 대한 정보를 가져오는 중입니다.
# 지원에 대한 정보를 가져오는 중입니다.
# 지캠단편 2017에 대한 정보를 가져오는 중입니다.
# 진눈깨비 소년에 대한 정보를 가져오는 중입니다.
# 진진돌이 에볼루션에 대한 정보를 가져오는 중입니다.
# 진진돌이 제로에 대한 정보를 가져오는 중입니다.
# 질풍기획 시즌1에 대한 정보를 가져오는 중입니다.
# 질풍기획 시즌2에 대한 정보를 가져오는 중입니다.
# 집이 없어에 대한 정보를 가져오는 중입니다.
# 징글정글에 대한 정보를 가져오는 중입니다.
# 찌질의 역사에 대한 정보를 가져오는 중입니다.
# 차원이 다른 만화에 대한 정보를 가져오는 중입니다.
# 차차차에 대한 정보를 가져오는 중입니다.
# 찬란하지 않아도 괜찮아에 대한 정보를 가져오는 중입니다.
# 참새는 새!신부에 대한 정보를 가져오는 중입니다.
# 참치와 돌고래에 대한 정보를 가져오는 중입니다.
# 창궐에 대한 정보를 가져오는 중입니다.
# 창위의일루젼에 대한 정보를 가져오는 중입니다.
# 천국의 신화에 대한 정보를 가져오는 중입니다.
# 천국의 신화 6부에 대한 정보를 가져오는 중입니다.
# 천년구미호에 대한 정보를 가져오는 중입니다.
# 천사가 아니야에 대한 정보를 가져오는 중입니다.
# 천적에 대한 정보를 가져오는 중입니다.
# 철벽! 연애 시뮬레이션에 대한 정보를 가져오는 중입니다.
# 첩보의 별에 대한 정보를 가져오는 중입니다.
# 첩보의 별 시즌2에 대한 정보를 가져오는 중입니다.
# 첫사랑입니다만에 대한 정보를 가져오는 중입니다.
# 체스아일에 대한 정보를 가져오는 중입니다.
# 체크포인트에 대한 정보를 가져오는 중입니다.
# 초록인간에 대한 정보를 가져오는 중입니다.
# 최강전설 강해효에 대한 정보를 가져오는 중입니다.
# 출격! 반보트에 대한 정보를 가져오는 중입니다.
# 취사병 전설이 되다에 대한 정보를 가져오는 중입니다.
# 취업의소리에 대한 정보를 가져오는 중입니다.
# 치즈인더트랩 (재)에 대한 정보를 가져오는 중입니다.
# 카라멜마끼아또에 대한 정보를 가져오는 중입니다.
# 카오스어택에 대한 정보를 가져오는 중입니다.
# 칼부림에 대한 정보를 가져오는 중입니다.
# 캉타우에 대한 정보를 가져오는 중입니다.
# 커넥트에 대한 정보를 가져오는 중입니다.
# 커피우유신화에 대한 정보를 가져오는 중입니다.
# 컨트롤제트에 대한 정보를 가져오는 중입니다.
# 코끼리를 끌어안는 방법에 대한 정보를 가져오는 중입니다.
# 콘스탄쯔 이야기에 대한 정보를 가져오는 중입니다.
# 쿠베라에 대한 정보를 가져오는 중입니다.
# 크레이지 커피 캣에 대한 정보를 가져오는 중입니다.
# 크레이터에 대한 정보를 가져오는 중입니다.
# 크리퍼스큘에 대한 정보를 가져오는 중입니다.
# 클로즈업에 대한 정보를 가져오는 중입니다.
# 키드갱에 대한 정보를 가져오는 중입니다.
# 키드갱 시즌2에 대한 정보를 가져오는 중입니다.
# 키스우드에 대한 정보를 가져오는 중입니다.
# 킥에 대한 정보를 가져오는 중입니다.
# 킬더킹에 대한 정보를 가져오는 중입니다.
# 킬러 김빵빵에 대한 정보를 가져오는 중입니다.
# 킬러분식 (재)에 대한 정보를 가져오는 중입니다.
# 타인은 지옥이다에 대한 정보를 가져오는 중입니다.
# 타임인조선에 대한 정보를 가져오는 중입니다.
# 타투에 대한 정보를 가져오는 중입니다.
# 탈(TAL)에 대한 정보를 가져오는 중입니다.
# 탐구생활2에 대한 정보를 가져오는 중입니다.
# 탐구생활3에 대한 정보를 가져오는 중입니다.
# 탐구생활4-그대와 함께 하이킹에 대한 정보를 가져오는 중입니다.
# 태왕광개토에 대한 정보를 가져오는 중입니다.
# 터치! 메리크리스마스에 대한 정보를 가져오는 중입니다.
# 테러맨에 대한 정보를 가져오는 중입니다.
# 테제에 대한 정보를 가져오는 중입니다.
# 퇴마전쟁에 대한 정보를 가져오는 중입니다.
# 투명살인에 대한 정보를 가져오는 중입니다.
# 투명한 동거에 대한 정보를 가져오는 중입니다.
# 투엔티스에 대한 정보를 가져오는 중입니다.
# 트라우마에 대한 정보를 가져오는 중입니다.
# 트럼프에 대한 정보를 가져오는 중입니다.
# 트롤트랩에 대한 정보를 가져오는 중입니다.
# 특수 영능력 수사반에 대한 정보를 가져오는 중입니다.
# 틴맘에 대한 정보를 가져오는 중입니다.
# 팀 피닉스에 대한 정보를 가져오는 중입니다.
# 파도를 찾아라!에 대한 정보를 가져오는 중입니다.
# 파도의 주인에 대한 정보를 가져오는 중입니다.
# 파라다이스에 대한 정보를 가져오는 중입니다.
# 파리의 우리동네에 대한 정보를 가져오는 중입니다.
# 파우스트 인 러브에 대한 정보를 가져오는 중입니다.
# 판다독에 대한 정보를 가져오는 중입니다.
# 판타스틱 어른백서에 대한 정보를 가져오는 중입니다.
# 판타지스케치 - 더 게임에 대한 정보를 가져오는 중입니다.
# 패밀리 사이즈에 대한 정보를 가져오는 중입니다.
# 패밀리맨에 대한 정보를 가져오는 중입니다.
# 패션왕에 대한 정보를 가져오는 중입니다.
# 퍼스트 미션에 대한 정보를 가져오는 중입니다.
# 펀브로커에 대한 정보를 가져오는 중입니다.
# 펫다이어리에 대한 정보를 가져오는 중입니다.
# 펫다이어리2.런에 대한 정보를 가져오는 중입니다.
# 평범한 8반에 대한 정보를 가져오는 중입니다.
# 폭풍의 전학생에 대한 정보를 가져오는 중입니다.
# 폭풍의 전학생 - 리부트에 대한 정보를 가져오는 중입니다.
# 폰령에 대한 정보를 가져오는 중입니다.
# 푸들과 Dog거중에 대한 정보를 가져오는 중입니다.
# 푸른사막 아아루에 대한 정보를 가져오는 중입니다.
# 퓨어 이블에 대한 정보를 가져오는 중입니다.
# 프로젝트 X에 대한 정보를 가져오는 중입니다.
# 프리드로우에 대한 정보를 가져오는 중입니다.
# 프린세스 1~4부에 대한 정보를 가져오는 중입니다.
# 프린세스 5부에 대한 정보를 가져오는 중입니다.
# 프린스의 왕자에 대한 정보를 가져오는 중입니다.
# 프린스의 왕자 - 카페 드 쇼콜라 -에 대한 정보를 가져오는 중입니다.
# 플라스틱 걸에 대한 정보를 가져오는 중입니다.
# 플랫다이어리에 대한 정보를 가져오는 중입니다.
# 플로우에 대한 정보를 가져오는 중입니다.
# 플루타크 영웅전에 대한 정보를 가져오는 중입니다.
# 피리부는 남자에 대한 정보를 가져오는 중입니다.
# 피에는 피에 대한 정보를 가져오는 중입니다.
# 피터팬날다에 대한 정보를 가져오는 중입니다.
# 피플에 대한 정보를 가져오는 중입니다.
# 핑크레이디에 대한 정보를 가져오는 중입니다.
# 핑크레이디 클래식에 대한 정보를 가져오는 중입니다.
# 하나(HANA)에 대한 정보를 가져오는 중입니다.
# 하나의 하루에 대한 정보를 가져오는 중입니다.
# 하늘쌤은 피곤해에 대한 정보를 가져오는 중입니다.
# 하드캐리에 대한 정보를 가져오는 중입니다.
# 하루 3컷에 대한 정보를 가져오는 중입니다.
# 하르모니아에 대한 정보를 가져오는 중입니다.
# 하우스키퍼에 대한 정보를 가져오는 중입니다.
# 하이브에 대한 정보를 가져오는 중입니다.
# 하이브3에 대한 정보를 가져오는 중입니다.
# 한 살이라도 어릴 때에 대한 정보를 가져오는 중입니다.
# 한국만화 1990에 대한 정보를 가져오는 중입니다.
# 한국만화 또 다른 시선에 대한 정보를 가져오는 중입니다.
# 한국만화거장전에 대한 정보를 가져오는 중입니다.
# 한국만화거장전 : 만화보물섬에 대한 정보를 가져오는 중입니다.
# 한국만화거장전 : 순정만화특집에 대한 정보를 가져오는 중입니다.
# 한남동 케이하우스에 대한 정보를 가져오는 중입니다.
# 한번 더 해요에 대한 정보를 가져오는 중입니다.
# 한섬세대에 대한 정보를 가져오는 중입니다.
# 한줌물망초에 대한 정보를 가져오는 중입니다.
# 합격시켜주세용에 대한 정보를 가져오는 중입니다.
# 합법해적 파르페에 대한 정보를 가져오는 중입니다.
# 해피에 대한 정보를 가져오는 중입니다.
# 향수에 대한 정보를 가져오는 중입니다.
# 허니버니에 대한 정보를 가져오는 중입니다.
# 허니허니 웨딩에 대한 정보를 가져오는 중입니다.
# 헬58에 대한 정보를 가져오는 중입니다.
# 헬로 미스터 테디에 대한 정보를 가져오는 중입니다.
# 헬퍼에 대한 정보를 가져오는 중입니다.
# 헬퍼 2 : 킬베로스에 대한 정보를 가져오는 중입니다.
# 헬프탑에 대한 정보를 가져오는 중입니다.
# 혈액형에 관한 간단한 고찰에 대한 정보를 가져오는 중입니다.
# 혈투에 대한 정보를 가져오는 중입니다.
# 혜성같은 소년에 대한 정보를 가져오는 중입니다.
# 호곡에 대한 정보를 가져오는 중입니다.
# 호랑이형님에 대한 정보를 가져오는 중입니다.
# 호랭총각에 대한 정보를 가져오는 중입니다.
# 호러와 로맨스에 대한 정보를 가져오는 중입니다.
# 호러전파상에 대한 정보를 가져오는 중입니다.
# 홍시는 날 좋아해!에 대한 정보를 가져오는 중입니다.
# 홍차리브레에 대한 정보를 가져오는 중입니다.
# 화양연화 Pt.0 ＜SAVE ME＞에 대한 정보를 가져오는 중입니다.
# 화이트멜로우에 대한 정보를 가져오는 중입니다.
# 화장 지워주는 남자에 대한 정보를 가져오는 중입니다.
# 환상적인 소년에 대한 정보를 가져오는 중입니다.
# 환생동물학교에 대한 정보를 가져오는 중입니다.
# 황금의 핸드메이커에 대한 정보를 가져오는 중입니다.
# 황금짱순이에 대한 정보를 가져오는 중입니다.
# 후레자식에 대한 정보를 가져오는 중입니다.
# 후유증에 대한 정보를 가져오는 중입니다.
# 후유증 2에 대한 정보를 가져오는 중입니다.
# 흐드러지다에 대한 정보를 가져오는 중입니다.
# 히어로메이커에 대한 정보를 가져오는 중입니다.
# 힘내요 일본!-[릴레이웹툰]에 대한 정보를 가져오는 중입니다.
# AA에 대한 정보를 가져오는 중입니다.
# DEY 호러채널에 대한 정보를 가져오는 중입니다.
# Doll 체인지에 대한 정보를 가져오는 중입니다.
# ENT.에 대한 정보를 가져오는 중입니다.
# Here U Are에 대한 정보를 가져오는 중입니다.
# Ho!에 대한 정보를 가져오는 중입니다.
# LOST에 대한 정보를 가져오는 중입니다.
# MLB카툰에 대한 정보를 가져오는 중입니다.
# MODERN BOYS에 대한 정보를 가져오는 중입니다.
# MY OH에 대한 정보를 가져오는 중입니다.
# MZ에 대한 정보를 가져오는 중입니다.
# MZ-레이징 인페르노에 대한 정보를 가져오는 중입니다.
# N의등대-busted에 대한 정보를 가져오는 중입니다.
# N의등대-thecalling에 대한 정보를 가져오는 중입니다.
# N의등대-눈의등대에 대한 정보를 가져오는 중입니다.
# N의등대-도망자에 대한 정보를 가져오는 중입니다.
# OH, MY GOD!에 대한 정보를 가져오는 중입니다.
# Penguin loves Mev에 대한 정보를 가져오는 중입니다.
# SM 플레이어에 대한 정보를 가져오는 중입니다.
# S라인에 대한 정보를 가져오는 중입니다.
# wish-마녀의 시간에 대한 정보를 가져오는 중입니다.
# 10월 28일에 대한 정보를 가져오는 중입니다.
# 12차원 소년들에 대한 정보를 가져오는 중입니다.
# 17살, 그 여름날의 기적에 대한 정보를 가져오는 중입니다.
# 1인용 기분에 대한 정보를 가져오는 중입니다.
# 1초에 대한 정보를 가져오는 중입니다.
# 2011 미스테리 단편에 대한 정보를 가져오는 중입니다.
# 2012 지구가 멸망한다면?에 대한 정보를 가져오는 중입니다.
# 2013 전설의고향에 대한 정보를 가져오는 중입니다.
# 2014 네이버 웹툰, 왓 이프?에 대한 정보를 가져오는 중입니다.
# 2015 사이에 대한 정보를 가져오는 중입니다.
# 2015 소름에 대한 정보를 가져오는 중입니다.
# 2015 우주특집 단편에 대한 정보를 가져오는 중입니다.
# 2016 비명에 대한 정보를 가져오는 중입니다.
# 2016 학교 다녀오겠습니다에 대한 정보를 가져오는 중입니다.
# 2017 멋진 신세계에 대한 정보를 가져오는 중입니다.
# 2017 사이다를 부탁해!에 대한 정보를 가져오는 중입니다.
# 2018 루키 단편선-지옥캠프에 대한 정보를 가져오는 중입니다.
# 2018 재생금지에 대한 정보를 가져오는 중입니다.
# 2019 병영일기에 대한 정보를 가져오는 중입니다.
# 203호 저승사자에 대한 정보를 가져오는 중입니다.
# 27-10에 대한 정보를 가져오는 중입니다.
# 2D남친 별책부록에 대한 정보를 가져오는 중입니다.
# 2인용 인간에 대한 정보를 가져오는 중입니다.
# 2호선 세입자에 대한 정보를 가져오는 중입니다.
# 35cm에 대한 정보를 가져오는 중입니다.
# 3P에 대한 정보를 가져오는 중입니다.
# 3단합체김창남에 대한 정보를 가져오는 중입니다.
# 3인칭에 대한 정보를 가져오는 중입니다.
# 5kg을 위하여에 대한 정보를 가져오는 중입니다.
# 8월의 눈보라에 대한 정보를 가져오는 중입니다.

# %%
# pick_list=[]
# def pick(*args):# 0<args<839
#     pick_toon=pd.read_csv('all_info.csv', encoding='cp949')
#     df_pick=pd.DataFrame([], columns=['제목', '작가', '연재상태'])
#     for arg in args:
    
#         df_pick=df_pick.append(pick_toon.loc[arg])
#     return df_pick

# %%
def pick(*args):# 0<args<839
    pick_toon=pd.read_csv('all_info.csv', encoding='cp949')
    
#     pick_toon=pd.DataFrame(pick_toon, columns=['제목','작가','연재상태'])
    pick_title=[]
    for arg in args:
        pick_title.append(pick_toon.loc[arg-1,'제목'])
#     return pick_toon
    return pick_title

# %%
pick_title=pick(1,11,445)

# %%
def find_genre(title):
    genre_url='https://comic.naver.com/webtoon/genre.nhn'
    genre_list=['episode','omnibus','story','daily','comic','fantasy','action','drama','pure','sensibility','thrill','historical','sports']
    title_genre=[]
    for genre in genre_list:
        params={
            'genre': genre
        }
        genre_resp=requests.get(genre_url, params=params)
        genre_soup=BeautifulSoup(genre_resp.content,'html.parser')
#         for title in pick_title:
#             print("{}은 {}장르입니다.".format(title, genre)
        if bool(genre_soup.find_all('a',text=title)):
            title_genre.append(genre)
        else:
            pass
    return title_genre

# %%
pick_dict={}
for title in pick_title:
    pick_dict.setdefault(title, find_genre(title))

# %%
pick_dict
# Out:
# {'가담항설': ['story', 'comic', 'fantasy', 'historical'],
#  '강변살다': ['story', 'drama', 'pure'],
#  '약한영웅': ['episode', 'action']}
