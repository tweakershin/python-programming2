# %%
import pygame
import tkinter
from tkinter import *
from tkinter import ttk
import pandas as pd

window=tkinter.Tk()
window.title("At this moment! Top 10 from contries")
window.geometry("1920x1080")
window.resizable(True, True)
temp = pd.read_csv('temp.csv')
pygame.init()
############################      box frame    ####################################

temp_nlist={}   
temp_blist={}   
temp_ylist={}   
temp_yjlist={}   


def raise_frame(frame):
    frame.tkraise()


f1 = Frame(window)
f2 = Frame(window)
f3 = Frame(window)
f4 = Frame(window)
f5 = Frame(window)
f6 = Frame(window)
f7 = Frame(window)
f8 = Frame(window)
f9 = Frame(window)
f10 = Frame(window)


for frame in (f1, f2, f3, f4, f5, f6, f7, f8, f9, f10):
    frame.grid(row=6, column=4, sticky='news')

Button(f1, text='Go to Rank 2', command=lambda:raise_frame(f2)).grid(row = 6, column = 1)
Button(f2, text='Go to Rank 3', command=lambda:raise_frame(f3)).grid(row = 6, column = 1)
Button(f3, text='Go to Rank 4', command=lambda:raise_frame(f4)).grid(row = 6, column = 1)
Button(f4, text='Go to Rank 5', command=lambda:raise_frame(f5)).grid(row = 6, column = 1)
Button(f5, text='Go to Rank 6', command=lambda:raise_frame(f6)).grid(row = 6, column = 1)
Button(f6, text='Go to Rank 7', command=lambda:raise_frame(f7)).grid(row = 6, column = 1)
Button(f7, text='Go to Rank 8', command=lambda:raise_frame(f8)).grid(row = 6, column = 1)
Button(f8, text='Go to Rank 9', command=lambda:raise_frame(f9)).grid(row = 6, column = 1)
Button(f9, text='Go to Rank 10', command=lambda:raise_frame(f10)).grid(row = 6, column = 1)
Button(f10, text='Go back to rank 1', command=lambda:raise_frame(f1)).grid(row = 6, column = 1)

raise_frame(f1)

############################      rank 1    ####################################    

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f1, image=temp_nlist[i]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f1, image=temp_blist[i]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f1, image=temp_ylist[i]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f1, image=temp_yjlist[i]).grid(row=i+1, column=3)  
    label = tkinter.Label(f1, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 0)
image_maker('Baidu', 1, 0)
image_maker('Yahoo', 2, 0)
# image_maker('Yahoo_jp', 3, 0)

def naver_play():
    pygame.mixer.music.load("naver0.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu0.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo0.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr0.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[0]['Naver']
Button(f1,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[0]['tr_b']
Button(f1,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[0]['tr_y']
Button(f1,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[0]['tr_jp']
Button(f1,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)
############################      rank 2    #################################### 

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f2, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f2, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f2, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f2, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f2, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 1)
image_maker('Baidu', 1, 1)
image_maker('Yahoo', 2, 1)
# image_maker('Yahoo_jp', 3, 1)

def naver_play():
    pygame.mixer.music.load("naver1.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu1.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo1.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr1.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[1]['Naver']
Button(f2,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[1]['tr_b']
Button(f2,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[1]['tr_y']
Button(f2,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[1]['tr_jp']
Button(f2,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 3    #################################### 


def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f3, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f3, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f3, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f3, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f3, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 2)
image_maker('Baidu', 1, 2)
image_maker('Yahoo', 2, 2)
# image_maker('Yahoo_jp', 3, 2)

def naver_play():
    pygame.mixer.music.load("naver2.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu2.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo2.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr2.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[2]['Naver']
Button(f3,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[2]['tr_b']
Button(f3,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[2]['tr_y']
Button(f3,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[2]['tr_jp']
Button(f3,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 4    #################################### 


def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f4, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f4, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f4, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f4, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f4, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 3)
image_maker('Baidu', 1, 3)
image_maker('Yahoo', 2, 3)
# image_maker('Yahoo_jp', 3, 3)

def naver_play():
    pygame.mixer.music.load("naver3.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu3.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo3.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr3.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[3]['Naver']
Button(f4,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[3]['tr_b']
Button(f4,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[3]['tr_y']
Button(f4,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[3]['tr_jp']
Button(f4,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 5    #################################### 

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f5, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f5, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f5, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f5, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f5, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 4)
image_maker('Baidu', 1, 4)
image_maker('Yahoo', 2, 4)
# image_maker('Yahoo_jp', 3, 4)

def naver_play():
    pygame.mixer.music.load("naver4.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu4.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo4.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr4.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[4]['Naver']
Button(f5,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[4]['tr_b']
Button(f5,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[4]['tr_y']
Button(f5,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[4]['tr_jp']
Button(f5,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 6    ####################################

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f6, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f6, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f6, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f6, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f6, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 5)
image_maker('Baidu', 1, 5)
image_maker('Yahoo', 2, 5)
# image_maker('Yahoo_jp', 3, 5)

def naver_play():
    pygame.mixer.music.load("naver5.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu5.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo5.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr5.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[5]['Naver']
Button(f6,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[5]['tr_b']
Button(f6,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[5]['tr_y']
Button(f6,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[5]['tr_jp']
Button(f6,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 7    #################################### 

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f7, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f7, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f7, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f7, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f7, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 6)
image_maker('Baidu', 1, 6)
image_maker('Yahoo', 2, 6)
# image_maker('Yahoo_jp', 3, 6)

def naver_play():
    pygame.mixer.music.load("naver6.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu6.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo6.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr6.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[6]['Naver']
Button(f7,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[6]['tr_b']
Button(f7,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[6]['tr_y']
Button(f7,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[6]['tr_jp']
Button(f7,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 8    #################################### 

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f8, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f8, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f8, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f8, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f8, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 7)
image_maker('Baidu', 1, 7)
image_maker('Yahoo', 2, 7)
# image_maker('Yahoo_jp', 3, 7)

def naver_play():
    pygame.mixer.music.load("naver7.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu7.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo7.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr7.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[7]['Naver']
Button(f8,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[7]['tr_b']
Button(f8,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[7]['tr_y']
Button(f8,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[7]['tr_jp']
Button(f8,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 9    #################################### 

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f9, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f9, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f9, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f9, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f9, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 8)
image_maker('Baidu', 1, 8)
image_maker('Yahoo', 2, 8)
# image_maker('Yahoo_jp', 3, 8)

def naver_play():
    pygame.mixer.music.load("naver8.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu8.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo8.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr8.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[8]['Naver']
Button(f9,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[8]['tr_b']
Button(f9,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[8]['tr_y']
Button(f9,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[8]['tr_jp']
Button(f9,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)

############################      rank 10    #################################### 

def image_maker(Site, col, rank):
    for i in range(0,4):
        if col == 0:
            temp_nlist[i+ 4*rank]=tkinter.PhotoImage(file=f"naver_img{rank}{i}.png")
            tkinter.Label(f10, image=temp_nlist[i+4*rank]).grid(row=i+1, column=0)   
        elif col == 1:
            temp_blist[i+4*rank]=tkinter.PhotoImage(file=f"baidu_img{rank}{i}.png")
            tkinter.Label(f10, image=temp_blist[i+4*rank]).grid(row=i+1, column=1)
        elif col == 2:
            temp_ylist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_img{rank}{i}.png")
            tkinter.Label(f10, image=temp_ylist[i+4*rank]).grid(row=i+1, column=2)
#         else :
#             temp_yjlist[i+4*rank]=tkinter.PhotoImage(file=f"yahoo_jp_img{rank}{i}.png")
#             tkinter.Label(f10, image=temp_yjlist[i+4*rank]).grid(row=i+1, column=3)  
    label = tkinter.Label(f10, text = Site)
    label.grid(row = 5, column = col)
    label.config(font = ('현대하모니 L', 18, 'bold'))

image_maker('Naver', 0, 9)
image_maker('Baidu', 1, 9)
image_maker('Yahoo', 2, 9)
# image_maker('Yahoo_jp', 3, 9)

def naver_play():
    pygame.mixer.music.load("naver9.mp3") 
    pygame.mixer.music.play() 
def baidu_play():
    pygame.mixer.music.load("baidu9.mp3") 
    pygame.mixer.music.play() 
def yahoo_play():
    pygame.mixer.music.load("yahoo9.mp3") 
    pygame.mixer.music.play() 
def yahoo_jr_play():
    pygame.mixer.music.load("yahoo_jr9.mp3") 
    pygame.mixer.music.play() 

ranking_list0 = temp.loc[9]['Naver']
Button(f10,text=ranking_list0, command=naver_play).grid(row = 0, column = 0)
ranking_list1 = temp.loc[9]['tr_b']
Button(f10,text=ranking_list1, command=baidu_play).grid(row = 0, column = 1)
ranking_list2 = temp.loc[9]['tr_y']
Button(f10,text=ranking_list2, command=yahoo_play).grid(row = 0, column = 2)
ranking_list3 = temp.loc[9]['tr_jp']
Button(f10,text=ranking_list3, command=yahoo_jr_play).grid(row = 0, column = 3)



window.mainloop()
