# %% [markdown]
# # matplotlib

# %%
from matplotlib import pyplot as plt
# import matplotlib.pyplot as plt

# %%
# %matplotlib qt

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3])

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3])

# %% [markdown]
# # 선 그래프

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-24a6d41c5b66> in <module>
# ----> 1 arr
#
# NameError: name 'arr' is not defined

# %%
data1 = [1,4,6,8,10,14,18]
plt.plot(data1)
plt.show()

# %% [markdown]
# ## $$y=2{x^2}$$

# %%
import numpy as np
x = np.arange(-10, 10, .2)
y = 2*x**2 # 2*s^2

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 여러 그래프 그리기

# %% [markdown]
# #### 수식1.
# $$
# y_1=2x^2   \\
# y_2=3x+20  \\
# y_3=4x^3-20  \\
# $$

# %%
x = np.arange(-5, 5, .1)
y1 = 2*x**2
y2 = 3*x+100
y3 = x**3-20

# %%
# 방법1. 여러번 호출
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.show()

# %%
# 방법2. 한번에 호출
plt.plot(x,y1, x,y2, x,y3, x,x**4)
plt.show()

# %% [markdown]
# ### 여러 그래프창에 그리기

# %%
plt.plot(x, y1) # 처음 호출시 새로운 그래프 창 생성 -> 그래프 그림
fig = plt.figure() # 새로운 그래프 창 생성
plt.plot(x, y2) #새로운 그래프 창에 그림
print(fig)

# plt.figure(n) # qt 일때 확인 가능
# Out:
# Figure(432x288)

# %% [markdown]
# #### clf - 그래프 지우기 (clear figure)

# %%
x = np.arange(-5, 5, .1)
y1 = x**2-2
y2 = 20*np.cos(x)**2

plt.figure(1)
plt.plot(x, y1)

plt.figure(2)
plt.plot(x,y2)

plt.figure(1)
plt.plot(x,y2)

plt.figure(2)
plt.clf()
plt.plot(x,y1)

plt.show()

# %% [markdown]
# ### 하나의 그래프 창에서 영역 나누기

# %%
# plt.subplot(m, n, p)  mxn 행렬의 p번째 그려짐
plt.subplot()

# %% [markdown]
# ##### $$
# y_1=0.3(x-5)^2 +1 \\
# y_2=-1.5x+3 \\
# y_3=sin(x)^2 \\
# y_4=10e^{-x}+1
# $$

# %%
x = np.arange(-5, 5, .1)
y1 = 0.3*(x-5)**2 + 1
y2 = -1.5*x + 3
y3 = np.sin(x)**2
y4 = 10*np.exp(-x) + 1

# 2 x 2 행렬로 나누고 위치조정
plt.subplot(2, 2, 1)
plt.plot(x, y1)

plt.subplot(2,2,2)
plt.plot(x, y2)

plt.subplot(2,2,3)
plt.plot(x, y3)

plt.subplot(2,2,4)
plt.plot(x, y4)


plt.show()

# %%
import numpy as np

# 데이터 생성
x = np.arange(0, 10, 0.1)
y1 = 0.3*(x-5)**2 + 1
y2 = -1.5*x + 3
y3 = np.sin(x)**2 # NumPy에서 sin()은 np.sin()으로 입력
y4 = 10*np.exp(-x) + 1 # NumPy에서 exp()는 np.exp()로 입력

# 2 × 2 행렬로 이뤄진 하위 그래프에서 p에 따라 위치를 지정
plt.subplot(2,2,1) # p는 1
plt.plot(x,y1)

plt.subplot(2,2,2) # p는 2
plt.plot(x,y2)

plt.subplot(2,2,3) # p는 3
plt.plot(x,y3)

plt.subplot(2,2,4) # p는 4
plt.plot(x,y4)

plt.show()

# %% [markdown]
# ### 그래프의 출력 범위 지정하기

# %%
# plt.xlim(xmin, xmax)
# plt.ylim(ymix, ymax)

# %%
xmin, xmax = plt.xlim() # 현재 x축 범위
ymin, ymax = plt.ylim() # 현재 y축 범위

# %%
xmin, ymin, xmax, ymax
# Out:
# (0.0, 0.0, 1.0, 1.0)

# %%
x = np.linspace(-4, 4,100) # [-4, 4] 범위에서 100개의 값 생성
y1 = x**3  
y2 = 10*x**2 - 2

plt.plot(x, y1, x, y2)
#  =
# plt.plot(x, y1)
# plt.plot(x, y2)
plt.show()

# %% [markdown]
# #### 범위지정

# %%
plt.plot(x, y1, x, y2)
plt.xlim(-1, 1)
plt.ylim(-3, 3)
plt.show()

# %%
fmt = '[color][line_style][marker]'

# %% [markdown]
# # matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(100)
y = x*3 +1000

# %%
# %matplotlib inline

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.show()

# %%
x = np.arange(-10, 11)
y1 = x * 4
y2 = x**2

# %%
plt.plot(x, y1)
plt.plot(x, y2)
plt.title('Title')
plt.legend(['x*4', 'x^2'])

plt.show()

# %%
x = np.linspace(1, 100, 12)
y1 = np.log(x)
y2 = -np.log(x)
y3 = 3/x

# %%
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.title('Test2')
plt.legend(['log(x)', '-log(x)', 'x*3'])
plt.show()

# %%
apple_price = [93.95, 112.15, 104.5, 144.85, 169]
ms_price= [39, 50, 57, 69, 95]
year = [2014, 2015, 2016, 2017, 2018]

# %%
plt.plot(year, apple_price)
plt.plot(year, ms_price)
plt.xlabel('Year')
plt.ylabel('apple_price(apple)')
plt.show()

# %%
plt.plot(year, apple_price, year, ms_price)
plt.xlabel('Year')
plt.ylabel('apple_price(apple)')
plt.show()

# %% [markdown]
# ### Style

# %%
#  색깔(color), 마커(marker), 선 종류(line style)의 순서로 지정
# red square --
# 색상: https://matplotlib.org/examples/color/named_colors.html

plt.title("'rs--' style plot ")

plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.show()

# %% [markdown]
# ## 색상
#
# <table class="table">
# <thead><tr>
# <th>문자열</th>
# <th>약자</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>blue</code></td>
# <td><code>b</code></td>
# </tr>
# <tr>
# <td><code>green</code></td>
# <td><code>g</code></td>
# </tr>
# <tr>
# <td><code>red</code></td>
# <td><code>r</code></td>
# </tr>
# <tr>
# <td><code>cyan</code></td>
# <td><code>c</code></td>
# </tr>
# <tr>
# <td><code>magenta</code></td>
# <td><code>m</code></td>
# </tr>
# <tr>
# <td><code>yellow</code></td>
# <td><code>y</code></td>
# </tr>
# <tr>
# <td><code>black</code></td>
# <td><code>k</code></td>
# </tr>
# <tr>
# <td><code>white</code></td>
# <td><code>w</code></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## 마커
# <table class="table">
# <thead><tr>
# <th>마커 문자열</th>
# <th>의미</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>.</code></td>
# <td>point marker</td>
# </tr>
# <tr>
# <td><code>,</code></td>
# <td>pixel marker</td>
# </tr>
# <tr>
# <td><code>o</code></td>
# <td>circle marker</td>
# </tr>
# <tr>
# <td><code>v</code></td>
# <td>triangle_down marker</td>
# </tr>
# <tr>
# <td><code>^</code></td>
# <td>triangle_up marker</td>
# </tr>
# <tr>
# <td><code>&lt;</code></td>
# <td>triangle_left marker</td>
# </tr>
# <tr>
# <td><code>&gt;</code></td>
# <td>triangle_right marker</td>
# </tr>
# <tr>
# <td><code>1</code></td>
# <td>tri_down marker</td>
# </tr>
# <tr>
# <td><code>2</code></td>
# <td>tri_up marker</td>
# </tr>
# <tr>
# <td><code>3</code></td>
# <td>tri_left marker</td>
# </tr>
# <tr>
# <td><code>4</code></td>
# <td>tri_right marker</td>
# </tr>
# <tr>
# <td><code>s</code></td>
# <td>square marker</td>
# </tr>
# <tr>
# <td><code>p</code></td>
# <td>pentagon marker</td>
# </tr>
# <tr>
# <td><code>*</code></td>
# <td>star marker</td>
# </tr>
# <tr>
# <td><code>h</code></td>
# <td>hexagon1 marker</td>
# </tr>
# <tr>
# <td><code>H</code></td>
# <td>hexagon2 marker</td>
# </tr>
# <tr>
# <td><code>+</code></td>
# <td>plus marker</td>
# </tr>
# <tr>
# <td><code>x</code></td>
# <td>x marker</td>
# </tr>
# <tr>
# <td><code>D</code></td>
# <td>diamond marker</td>
# </tr>
# <tr>
# <td><code>d</code></td>
# <td>thin_diamond marker</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## 선 모양
# <table class="table">
# <thead><tr>
# <th>선 스타일 문자열</th>
# <th>의미</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>-</code></td>
# <td>solid line style</td>
# </tr>
# <tr>
# <td><code>--</code></td>
# <td>dashed line style</td>
# </tr>
# <tr>
# <td><code>-.</code></td>
# <td>dash-dot line style</td>
# </tr>
# <tr>
# <td><code>:</code></td>
# <td>dotted line style</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## 기타 스타일
#
# <table class="table">
# <thead><tr>
# <th>스타일 문자열</th>
# <th>약자</th>
# <th>의미</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>color</code></td>
# <td><code>c</code></td>
# <td>선 색깔</td>
# </tr>
# <tr>
# <td><code>linewidth</code></td>
# <td><code>lw</code></td>
# <td>선 굵기</td>
# </tr>
# <tr>
# <td><code>linestyle</code></td>
# <td><code>ls</code></td>
# <td>선 스타일</td>
# </tr>
# <tr>
# <td><code>marker</code></td>
# <td></td>
# <td>마커 종류</td>
# </tr>
# <tr>
# <td><code>markersize</code></td>
# <td><code>ms</code></td>
# <td>마커 크기</td>
# </tr>
# <tr>
# <td><code>markeredgecolor</code></td>
# <td><code>mec</code></td>
# <td>마커 선 색깔</td>
# </tr>
# <tr>
# <td><code>markeredgewidth</code></td>
# <td><code>mew</code></td>
# <td>마커 선 굵기</td>
# </tr>
# <tr>
# <td><code>markerfacecolor</code></td>
# <td><code>mfc</code></td>
# <td>마커 내부 색깔</td>
# </tr>
# </tbody>
# </table>

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("Example")
plt.show()

# %%
plt.title("limit")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50) # x의 범위
plt.ylim(-10, 30) # y의 범위
plt.show()

# %%
#grid
plt.title("limit")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.grid(True)
plt.show()

# %%
# np.random.seed(42)
np.random.randn(3)
# Out:
# array([-0.90802408, -1.4123037 ,  1.46564877])

# %%
import numpy as np
## FigureSize
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()
# Out:
# array([1.76405235, 0.40015721])

# %%
import numpy as np
f1 = plt.figure(figsize=(15, 2))
plt.title("figure size : (15, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(432x288) 218002936
# Figure(432x288) 218002936

# %%
x = np.arange(1, 10)
y2 = x *3
y3 = x/3
plt.subplot(2, 1, 1) # sublpot을 나누고 첫번째 (2by1행렬)
plt.plot(x,y2)
plt.subplot(2, 1, 2) # sublpot을 나누고 두번째
plt.plot(x,y3)
plt.show()

# %% [markdown]
# ## plot종류

# %%
year
# Out:
# [2014, 2015, 2016, 2017, 2018]

# %%
apple_price
# Out:
# [93.95, 112.15, 104.5, 144.85, 169]

# %%
ms_price
# Out:
# [39, 50, 57, 69, 95]

# %%
plt.bar(year, apple_price)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(year, apple_price, )
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(year,apple_price)
plt.bar(year,ms_price)
plt.show()

# %%
plt.bar(year,apple_price, width=1)
plt.bar(year, ms_price, width=1)
plt.show()

# %%
plt.bar(year,apple_price, width=.5)
plt.bar(year, ms_price, width=.5)

plt.show()

# %%
plt.bar(year,apple_price, width=.5, label='apple')
plt.bar(year, ms_price, bottom=apple_price, width=.5, label='ms')
plt.legend()
plt.show()

# %%
year = np.array(year) # 2014~ 2018:  5

# %%
_year = np.arange(5) # 0~4 
width = .35

plt.bar(_year, apple_price, width=width, label='apple')
plt.bar(_year+width, ms_price, width=width, label='ms')
plt.xticks(_year+width/2, year)
plt.legend()
plt.show()

# %%
plt.scatter(year, apple_price)
plt.scatter(year, ms_price)
plt.xlabel('Year')
plt.ylabel('apple_price(apple)')
plt.show()

# %%
plt.scatter(year, apple_price, s=np.array(apple_price)**3/10000)
plt.scatter(year, ms_price, s=np.array(ms_price)**3/1000)
plt.xlabel('Year')
plt.ylabel('apple_price(apple)')
plt.show()

# %%
data = {
    'ms_price': np.array(ms_price),
    'apple_price': np.array(apple_price),
}
plt.scatter(year, apple_price, s=data['apple_price']**3/10000)
plt.scatter(year, ms_price, s=data['ms_price']**3/1000)
plt.xlabel('Year')
plt.ylabel('apple_price(apple)')
plt.show()

# %%
data = {
    'ms_price': np.array(ms_price),
    'apple_price': np.array(apple_price),
}
plt.scatter(year, apple_price, s=data['apple_price']**3/10000)
plt.scatter(year, ms_price, s=data['ms_price']**3/1000)
plt.xlabel('Year')
plt.ylabel('apple_price(apple)')

plt.axis([2013, 2019, 0, 200])
plt.show()

# %%
data = {
    'ms_price': np.array(ms_price),
    'apple_price': np.array(apple_price),
}
plt.scatter(year, apple_price, s=data['apple_price']**3/10000)
plt.scatter(year, ms_price, s=data['ms_price']**3/1000)
plt.xlabel('Year')
plt.ylabel('apple_price(apple)')

plt.axis([2013, 2019, 0, 200])
plt.annotate('Max', xy=(2017, apple_price[-2]), xytext=(2018.5, 180), arrowprops=dict(facecolor='black', shrink=0.05),)
plt.show()

# %%
# 3d
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib import pyplot as plt

# 3D Sample data만들기
mu_vec1 = np.array([0,0,0])
cov_mat1 = np.array([[1,0,0],[0,1,0],[0,0,1]]) 

class1_sample = np.random.multivariate_normal(mu_vec1, cov_mat1, 20)
class2_sample = np.random.multivariate_normal(mu_vec1 + 1, cov_mat1, 20)
class3_sample = np.random.multivariate_normal(mu_vec1 + 2, cov_mat1, 20)


fig = plt.figure(figsize=(8,8)) # figure -> Canvas
ax = fig.add_subplot(111, projection='3d')
   
ax.scatter(class1_sample[:,0], class1_sample[:,1], class1_sample[:,2], 
           marker='x', color='blue', s=40, label='class 1')
ax.scatter(class2_sample[:,0], class2_sample[:,1], class2_sample[:,2], 
           marker='o', color='green', s=40, label='class 2')
ax.scatter(class3_sample[:,0], class3_sample[:,1], class3_sample[:,2], 
           marker='^', color='red', s=40, label='class 3')

ax.set_xlabel('variable X')
ax.set_ylabel('variable Y')
ax.set_zlabel('variable Z')

plt.title('3D Scatter Plot')
     
plt.show()

# %%
# Histogram
import numpy as np
import random
import math
from matplotlib import pyplot as plt

data = np.random.normal(0, 20, 1000) 

bins = np.linspace(math.ceil(min(data)), 
                   math.floor(max(data)),
                   20) # fixed number of bins

plt.xlim([min(data)-5, max(data)+5])

plt.hist(data, bins=bins, alpha=.2)
plt.title('Gaussian')
plt.xlabel('variable X (20 evenly spaced bins)')
plt.ylabel('count')

plt.show()

# %%
arr = np.random.rand(1000) *100
arr2 = np.random.rand(2) * 100 +200
arr3 = -(np.random.rand(2) * 100 +200)

arr = np.hstack((arr,arr2, arr3))

plt.boxplot(arr)
plt.show()
