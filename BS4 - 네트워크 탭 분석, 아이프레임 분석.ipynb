# %%
# bitcoin_url = "https://crix-api-cdn.upbit.com/v1/crix/trades/days"
time_list = ['240', '60', '30', '10']
bitcoin_url = "https://crix-api-cdn.upbit.com/v1/crix/candles/minutes/"

url_list = []
for time in time_list:
    url_list.append("{}{}".format(bitcoin_url, time))

print(url_list)

count = 200
params ={
    'code': 'CRIX.UPBIT.KRW-BTC',
    'count': count
}

# %%
resp = requests.get(bitcoin_url, params=params)
resp

# %% [markdown]
# # 블로그 상세페이지 가져오기

# %%
import requests
from bs4 import BeautifulSoup

# %%
blog_url = "https://search.naver.com/search.naver"
params = dict(
    where='post',
    query="놀란 라이언"
)

# %%
resp = requests.get(blog_url, params=params)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content)
blog_list = soup.find_all('li', class_='sh_blog_top')
for blog in blog_list:
    a_tag = blog.find('a')
    link = a_tag['href']
    detail_resp = requests.get(link)
#     print(detail_resp)
    detail_soup = BeautifulSoup(detail_resp.content)
#     print(detail_soup)
    detail_iframe = detail_soup.find('iframe', id="mainFrame")
    
    iframe_src = detail_iframe['src']
    iframe_src = "https://blog.naver.com{}".format(iframe_src)
    print(iframe_src)
#     print(detail_iframe)
    iframe_resp = requests.get(iframe_src)
    iframe_soup = BeautifulSoup(iframe_resp.content)
    blog_post = iframe_soup.find('div', class_="se_doc_viewer se_body_wrap se_theme_transparent")
    print(blog_post)
    break
# Out:
# https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552&from=search&redirect=Log&widgetTypeCall=true&directAccess=false
# <div class="se_doc_viewer se_body_wrap se_theme_transparent" data-docversion="1.0" id="SEDOC-1533733035862-1096909084">
# <div class="se_doc_header_start" id="SEDOC-1533733035862-1096909084_se_doc_header_start"></div>
# <!-- SE_DOC_HEADER_START -->
# <div class="se_viewer_head" id="SEDOC-1533733035862-1096909084_viewer_head"></div>
# <div class="se_component_wrap">
# <div class="se_component se_documentTitle documentTitle_blog is-fill">
# <div class="se_sectionArea is-fill se_align-left">
# <!-- -->
# <div class="blog2_series">
# <a class="pcol2" href="/PostList.nhn?blogId=jjys9047&amp;categoryNo=31&amp;from=postList" onclick="clickcr(this,'pst.category','','',event);">MLB의 17가지불멸의기록</a>
# </div>
# <div class="pcol1">
# <!-- -->
# <!-- SE_DOC_HEADER_TITLE_TOP-->
# <div class="se_doc_title_top" id="SEDOC-1533733035862-1096909084_se_doc_title_top"></div>
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_D2">
# <div class="se_editView se_title">
# <div class="se_textView">
# <h3 class="se_textarea">
# <!-- -->놀란 라이언의 통산 5714탈삼진<!-- -->
# </h3>
# </div>
# </div>
# </div>
# </div><!-- SE_DOC_HEADER_TITLE_MIDDLE-->
# <div class="se_doc_title_middle" id="SEDOC-1533733035862-1096909084_se_doc_title_middle"></div>
# <!-- SE_DOC_HEADER_CONTENTS_START -->
# <!-- -->
# </div>
# <div class="blog2_container">
# <span class="writer">
# <span class="area_profile"><a class="link" href="https://blog.naver.com/jjys9047" onclick="clickcr(this,'pst.profile','','',event);" target="_top"><img alt="프로파일" class="img" src="https://blogpfthumb-phinf.pstatic.net/MjAxODA5MDhfMTI5/MDAxNTM2NDA5NTU1NzMx.0ZJwUsdyyUnA4jiHOGRJDcZ79-f3bn61BiFZHxl5OmYg.gZj-jmqlV4SPlII-i2X-jReTwPFtRBo8RvuPG9pN80cg.PNG.jjys9047/20130115_0122521.png?type=s1"/></a></span>
# <span class="nick"><a class="link pcol2" href="https://blog.naver.com/jjys9047" onclick="clickcr(this,'pst.username','','',event);" target="_top">Daikoku</a></span>
# </span>
# <i class="dot"> ・ </i>
# <span class="se_publishDate pcol2">2018. 6. 25. 23:10</span>
# </div>
# <div class="blog2_post_function">
# <a class="url pcol2 _setClipboard _returnFalse _se3copybtn _transPosition" href="#" id="copyBtn_221306678552" style="cursor:pointer;" title="https://blog.naver.com/jjys9047/221306678552">URL 복사</a>
# <a class="btn_buddy btn_addbuddy pcol2 _buddy_popup_btn _returnFalse" href="#" onclick="clickcr(this,'pst.addnei','','',event);"><i class="ico"></i> 이웃추가<i class="aline"></i></a>
# <div class="overflow_menu">
# <a area-expanded="false" area-haspopup="true" class="btn_overflow_menu _open_overflowmenu pcol2 _param(221306678552) _returnFalse" href="#" role="button"><span class="blind">본문 기타 기능</span></a>
# <div area-hidden="true" class="lyr_overflow_menu" id="overflowmenu-221306678552">
# <a class="naverTranslateNavigationBox _goTran _param(221306678552) _returnFalse" href="#">번역보기<span class="ico_translation _goTran _param(221306678552)"></span></a>
# </div>
# </div>
# <input alt="url" class="copyTargetUrl" style="display:none;" title="URL 복사" type="text" value="https://blog.naver.com/jjys9047/221306678552"/>
# </div>
# <!-- -->
# <!-- SE_DOC_HEADER_CONTENTS_END -->
# <!-- SE_DOC_HEADER_TITLE_BOTTOM-->
# <div class="se_doc_title_bottom" id="SEDOC-1533733035862-1096909084_se_doc_title_bottom"></div>
# </div>
# </div>
# </div>
# <div class="location_component">
# <div class="location">
# </div>
# </div>
# <!-- {{{$SE3-CONTENTS_HEADER}}} -->
# <!-- SE_DOC_HEADER_END -->
# <div class="se_doc_header_end" id="SEDOC-1533733035862-1096909084_se_doc_header_end"></div>
# <div class="se_doc_contents_start" id="SEDOC-1533733035862-1096909084_se_doc_contents_start"></div>
# <!-- SE_DOC_CONTENTS_START -->
# <div class="se_component_wrap sect_dsc __se_component_area">
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-left">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span style="color: rgb(34, 34, 34);">메이저리그 공식 홈페이지인 MLB.com 에서 야구가 존속하는 한 영원히 존속할 불멸의 기록 17개를 소개한 바 있다. 기록에 대해 주관적인 의견을 더해본다. </span><br/><br/><span style="color: rgb(34, 34, 34);">2. 놀란 라이언의 통산 5714 탈삼진</span><br/><span style="color: rgb(34, 34, 34);">   </span><span style="color: rgb(34, 34, 34);"> </span><span style="color: rgb(34, 34, 34);">이전 포스팅에서 언급했던 이치로의 262안타보다는 시각적으로 훨씬 끔찍해 보인다. 그래도 포스팅이라고 올리는데 아무런 논거도 없이 숫자를 봐라! 저게 사람이 이뤄낼 수 있는 기록이냐? 라고 쓸 순 없지 않는가. 이제부터 까보자 놀란 라이언의 기록.</span><br/><span style="color: rgb(34, 34, 34);">   </span><span style="color: rgb(34, 34, 34);"> 탈삼진부터 신명나게 까보자. 보통 선발투수의 성적을 비교할 때 가장 많이 사용하는 클래식 스텟이 몇가지 있다. '탈삼진','승수','방어율' . 그래서 선발투수가 탈삼진, 승수, 방어율에서 모두 최고 성적을 기록하면 트리플크라운이라고 해서 아주 명예롭게 여긴다. 이 중 세이버메트릭스(1)가 야구에 붐을 일으키면서 '승수'는 투수의 실력과는 상관없다는 이유(2)로 그 가치가 격하되었고, 반대로 탈삼진의 경우 수비의 도움을 받지 않고도 아웃카운트를 벌 수 있기 때문에 그 가치가 격상된 바 있다. 여기까지는 에피타이저!</span><br/><span style="color: rgb(34, 34, 34);">   </span><span style="color: rgb(34, 34, 34);"> </span><span style="color: rgb(51, 51, 51);">첫번째로 메이저리그 역사를 뒤져보자. 역대 4000탈삼진 이상을 잡아낸 투수는 4명뿐이다. </span><br/><br/><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_table table_layout1">
# <div class="se_sectionArea se_align-left">
# <div class="se_editArea">
# <div class="se_table_wrap" data-attachment-id="" id="SEDOC-1533733035862-1096909084_table_0">
# <div class="se_table_innerWrap">
# <table class="se_table_col" style="width:100%;border-width: 0px; border-color: rgb(212, 212, 212);">
# <tbody>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:48.67807%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">이름</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:51.32193%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">탈삼진</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:48.67807%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">놀란 라이언</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:51.32193%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">5714</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:48.67807%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">랜디 존슨</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:51.32193%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">4875</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:48.67807%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">로저 클레멘스</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:51.32193%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">4672</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:48.67807%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">스티브 칼튼</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:51.32193%;height:45.0px;background-color:;border-width: 2px; border-style: solid; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea">4136</div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_table", "docVersion" : "1.0", "id" :"SEDOC-1533733035862-1096909084_table_0" , "data" : { "baseElId" : "SEDOC-1533733035862-1096909084_table_0", "columnCount": "2"}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-left">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 현대 야구의 룰이 정착된 라이브볼 시대 이후 한 시즌 최다 삼진 개수는 마찬가지로 포스팅의 주인공 놀란 라이언인데 1973년 383개의 탈삼진을 잡아낸 바 있다. 불가능에 대한 도전이므로 놀란 라이언의 한시즌 최다 383개의 탈삼진을 매년 기록하며 15년동안 메이저리그에서 선발투수로 공을 던진다고 가정하면 5745개로 간신히 놀란라이언의 탈삼진 개수를 뛰어넘을 수 있다. 와우! </span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 몽상에서 벗어나 현실적인 계산이 필요한 시점이다. 놀란 라이언 역시 27시즌 동안 300탈삼진을 넘긴 것은 단 6시즌 뿐이었다. </span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 탈삼진능력을 평가하는 데 있어 단순 탈삼진의 개수도 중요하지만 이닝당 탈삼진 개수가 더 중요하게 판단된다. 전체 탈삼진 개수는 놀란 라이언의 경우에서도 볼 수 있듯이 철인이 모든 것을 이뤄낼 수 있기 때문이다.(물론 27시즌동안 건강하게 투수생활을 했다는 것 자체로 인간의 영역이 아니다.) 그래서 우리는 SO9(3)의 수치를 이용해 볼 생각이다.  우선 역대 메이저리그 SO9 값을 확인해 보면 9개 이상을 잡아낸 투수는 불과 11명뿐이고, 10이상을 기록한 투수는 아래 표에 쓰인 3명뿐이다.(1000이닝 이상)</span><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_table default">
# <div class="se_sectionArea se_align-left">
# <div class="se_editArea">
# <div class="se_table_wrap" data-attachment-id="" id="SEDOC-1533733035862-1096909084_table_1">
# <div class="se_table_innerWrap">
# <table class="se_table_col" style="width:100%;">
# <tbody>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:50.617283%;height:44.0px;background-color:;">
# <div class="se_cellArea">이름</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:49.382717%;height:44.0px;background-color:;">
# <div class="se_cellArea">SO9</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:50.617283%;height:44.0px;background-color:;">
# <div class="se_cellArea">랜디 존슨</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:49.382717%;height:44.0px;background-color:;">
# <div class="se_cellArea">10.6</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:50.617283%;height:44.0px;background-color:;">
# <div class="se_cellArea">케리 우드</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:49.382717%;height:44.0px;background-color:;">
# <div class="se_cellArea">10.3</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:50.617283%;height:44.0px;background-color:;">
# <div class="se_cellArea">페드로 마르티네즈</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:49.382717%;height:44.0px;background-color:;">
# <div class="se_cellArea">10.0</div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_table", "docVersion" : "1.0", "id" :"SEDOC-1533733035862-1096909084_table_1" , "data" : { "baseElId" : "SEDOC-1533733035862-1096909084_table_1", "columnCount": "2"}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-left">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 놀란 라이언의 시즌 383개 탈삼진과 달리 랜디 존슨의 10.6개 기록은 전 시즌을 평균내어 구한 실제값이므로 이를 통해 계산했을 경우 랜디존슨이 환생했을 때는 가능하다 정도의 작은 결론이나마 낼 수 있을 것이다.(물론 랜디 존슨 정도의 투수가 다시 나타날 수 있을까?라고 질문한다면 답변하긴 어려울 것이다.(4) 인정! 근데 이건 모두 불가능에 대한 도전이다.)</span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 랜디 존슨 정도의 SO9(이라고 쓰고 개사기라고 읽는다)를 가진 투수가 놀란 라이언의 5714개 탈삼진을 얻어내기 위해서는 통산 4851이닝을 던져야만 한다. 'baseball reference'(5)에 따르면 통산 4000이닝을 넘게 던진 투수는 정확하게 40명뿐이다. 메이저리그 역사에 길이길이 남을 투수가 된다면 가능할지도 모른다. </span><span style="color:rgb(034,034,034);">그러나 여기에는 중대한 오류가 있다.</span><br/><br/><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_table default">
# <div class="se_sectionArea se_align-left">
# <div class="se_editArea">
# <div class="se_table_wrap" data-attachment-id="" id="SEDOC-1533733035862-1096909084_table_2">
# <div class="se_table_innerWrap">
# <table class="se_table_col" style="width:100%;border-width: 0px; border-color: rgb(212, 212, 212);">
# <tbody>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:100.0%;height:64.0px;background-color:;border-width: 0px; border-color: rgb(212, 212, 212);">
# <div class="se_cellArea"><span class="se_fs_T1"><b>투수분업화</b></span></div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_table", "docVersion" : "1.0", "id" :"SEDOC-1533733035862-1096909084_table_2" , "data" : { "baseElId" : "SEDOC-1533733035862-1096909084_table_2", "columnCount": "1"}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-left">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 현대의 투수들은 시즌 300이닝은 고사하고 250이닝도 거의 던지지 않는다. 2017년을 기준으로 메이저리그에서 200이닝 고지에 오른 투수는 15명으로 10년전인 2005년의 50명에 비해 크게 줄었다. 이 역시 통계적으로 선발투수가 3번째 타선을 만나게 되었을 때 피안타율이 급격히 상승한다는 세이버적 관점때문이다.(6) 개인적으로는 이 개념자체가 득이 되지는 않을거라고 생각한다. 결국 볼펜을 갈아서 성적을 유지하겠다는 기업가적 수치놀음에 지나지 않는다는 생각이다. 내 생각은 여기까지</span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 상기한 이유로 17시즌 가장 많은 이닝을 소화한 크리스 세일은 214.1이닝을 소화했을 뿐이다. </span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> </span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> 결과적으로 17년 크리스 세일과 같은 폼으로 매년 214.1이닝을 던지며 랜디 존슨급의 SO9 능력을 가지고 22시즌하고도 반시즌을 더 해야(</span><span style="color:rgb(034,034,034);">4851/214.1 = 22.66) 놀란 라이언의 탈삼진 개수를 뛰어넘을 수 있다! </span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> </span><br/><br/><span style="color:rgb(034,034,034);">( Warning! 이 수치는 인간이 나이가 들어감에 따른 자연적인 체력,근력의 감소, 노화 등은 전혀 고려하지 않은 수치임을 밝힙니다.)</span><br/><span style="color:rgb(034,034,034);">   </span><span style="color:rgb(034,034,034);"> </span><br/><br/><span style="color:rgb(034,034,034);"><b>참고 설명(야구 설명충이 되기 위한 밑밥)</b></span><br/><span style="color:rgb(034,034,034);">(1) 야구라는 스포츠 종목을 통계학적/수학적인 분석을 통해 이해하려는 방식이다. 다른 포지션의 야수들끼리의 선수로서의 가치에 대한 통일적분석, 나아가서는 투수와 야수라는 다른 방식의 경기방법을 가지고 있는 선수들간의 수치적인 비교를 위해 많은 계산식을 만들어냈고, 현재는 대부분의 메이저리그 구단에서 세이버메트릭스를 통해 분석한 선수들의 스탯에 의해 팀을 운영하고 있다. 이 탓에 현재 메이저리그의 감독(Manager라고 불림)이 진짜 매니저수준의 역할(선수 관리등)만 수행하는 경우가 많다. 기상천외한 작전이나 파격적인 라인업등에 대한 권한이 없는 경우가 많다는 이야기. </span><br/><span style="color:rgb(034,034,034);">(2) 선발투수의 경우 승리를 챙기기 위해서는 5이닝이상을 투구하여야 하며, 선발투수가 교체될 당시 팀이 이기고 있어야 하고, 동점상황이 발생하지 않은 채 경기가 종료되어야 한다. 이 때문에 5이닝 2실점을 한 경우라 하더라도 상대 투수가 5이닝1실점을 한 경우 승수를 얻을 수 없지만 5이닝 10실점을 하더라도 상대 투수가 5이닝 11실점을 한 경우에는 승수를 얻을 확률이 존재한다. </span><br/><span style="color:rgb(034,034,034);">(3) SO9, K/9 등으로 표시되는 값으로 야구의 정규이닝이 9이닝이기 때문에 전체 삼진개수를 9로 나눈 값을 사용한다. 계산식 그대로 9이닝당 잡아낼 수 있는 삼진의 개수를 의미한다. </span><br/><span style="color:rgb(034,034,034);">(4) 랜디 존슨과 케리 우드의 SO9 수치가 크게 차이나지 않는다고 볼 수 도 있지만(3경기에 1개 정도의 개수차이이므로) 랜디 존슨이 통산 4135.1이닝을 던진데 반해 케리 우드는 1380이닝을 던졌을 뿐이며 그마저도 381 이닝정도는 볼펜에서 던진 기록이다.(통상적으로 볼펜은 3타자 정도만을 상대하기 때문에 전력투구 비중이 높으며 이에 따라 SO9이 선발투수에 비해 높은 편이다.) </span><br/><span style="color:rgb(034,034,034);">(5) 메이저리그 기록 사이트 중 가장 공신력 있는 사이트 기본적인 정보는 무료로 공개되어 있으며, 각종 순위 등에 대한 정보는 돈을 지불해야 한다. (</span><a class="se_link" href="http://www.baseball-reference.com) " target="_blank"><span style="color:rgb(034,034,034);">www.baseball-reference.com)</span></a><br/><span style="color:rgb(034,034,034);">(6) 17년 기준 타자를 상대한 횟수에 따른 선발 투수 성적</span><br/><br/><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_table default">
# <div class="se_sectionArea se_align-left">
# <div class="se_editArea">
# <div class="se_table_wrap" data-attachment-id="" id="SEDOC-1533733035862-1096909084_table_3">
# <div class="se_table_innerWrap">
# <table class="se_table_col" style="width:100%;">
# <tbody>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">상대한 순서</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">타율</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.964285%;height:44.0px;background-color:;">
# <div class="se_cellArea">출루율</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.785715%;height:44.0px;background-color:;">
# <div class="se_cellArea">장타율</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:15.0%;height:44.0px;background-color:;">
# <div class="se_cellArea">OPS</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:18.035715%;height:44.0px;background-color:;">
# <div class="se_cellArea">타석 횟수</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">첫번째</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.250</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.964285%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.315</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.785715%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.417</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:15.0%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.731</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:18.035715%;height:44.0px;background-color:;">
# <div class="se_cellArea">43603</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">두번째</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.265</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.964285%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.331</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.785715%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.448</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:15.0%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.779</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:18.035715%;height:44.0px;background-color:;">
# <div class="se_cellArea">42324</div>
# </td>
# </tr>
# <tr>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">세번째</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.607143%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.272</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.964285%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.338</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:16.785715%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.463</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:15.0%;height:44.0px;background-color:;">
# <div class="se_cellArea">0.801</div>
# </td>
# <td class="se_cell se_align-center" colspan="1" rowspan="1" style="width:18.035715%;height:44.0px;background-color:;">
# <div class="se_cellArea">27565</div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_table", "docVersion" : "1.0", "id" :"SEDOC-1533733035862-1096909084_table_3" , "data" : { "baseElId" : "SEDOC-1533733035862-1096909084_table_3", "columnCount": "6"}}' type="text/data"></script>
# </div>
# <!-- SE_DOC_CONTENTS_END -->
# <div class="__se_doc_title_end" id="se_doc_contents_end"></div>
# <div class="se_doc_footer" id="SEDOC-1533733035862-1096909084_se_doc_footer"></div>
# </div>

# %% [markdown]
# ### iframe 실습

# %%
resp = requests.get("https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552&from=search&redirect=Log&widgetTypeCall=true&topReferer=http%3A%2F%2Flocalhost%3A8888%2Fnotebooks%2FDesktop%2F%25EA%25B3%25B5%25EB%25B6%2580%25EC%259E%2590%25EB%25A3%258C%2F%25EC%2588%2598%25EA%25B0%2595%25EC%2583%259D%25EC%259E%2590%25EB%25A3%258C%2Fipynb.ipynb&directAccess=false%22")

# %%
resp

# %%
soup3 = BeautifulSoup(resp.content, 'html.parser')
soup3

# %%
post_content = soup3.find('div', class_="se_doc_viewer se_body_wrap se_theme_transparent")
post_content

# %% [markdown]
# # 블로그 id 찾기

# %%
import requests
from bs4 import BeautifulSoup

# %%
blog_url = "https://search.naver.com/search.naver"
params = dict(
    where='post',
    query="놀란 라이언"
)

# %%
resp = requests.get(blog_url, params=params)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content)
blog_list = soup.find_all('li', class_='sh_blog_top')
for blog in blog_list:
    a_tag = blog.find('a')
    link = a_tag['href']
    print(link)
    
    #     print(detail_resp)
    # blog_id 가져오기
    break
    # logNo 가져오기
    
    # https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552
# Out:
# https://blog.naver.com/jjys9047?Redirect=Log&logNo=221306678552

# %%
import urllib

# %%
parse_link = urllib.parse.urlparse(link)
parse_link
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/jjys9047', params='', query='Redirect=Log&logNo=221306678552', fragment='')

# %%
parse_link.path[1:]
# Out:
# 'jjys9047'

# %%
log_str = parse_link.query.split('&')[1]
print(log_str)
# Out:
# logNo=221306678552

# %%
log_id = log_str.split('=')[1]
log_id
# Out:
# '221306678552'

# %%
log_no = parse_link.query

# %%
blogid = parse_link.path[1:]
print(blogid)
log_id
# Out:
# jjys9047
# '221306678552'

# %%
url = "https://blog.naver.com/PostView.nhn"

params = {
    'blogId': blogid,
    'logNo': log_id
}

resp = requests.get(url, params=params)

# %%
resp.url
# Out:
# 'https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552'

# %%
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'\r\n\r\n\r\n\r\n\r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n<html lang="ko">\r\n<head>\r\n<meta http-equiv="Pragma" content="no-cache" />\r\n<meta http-equiv="Expires" content="-1" />\r\n\r\n<meta name="referrer" content="always" />\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!--[if ie]>\r\n<style type="text/css">\r\nhtml {overflow: scroll; overflow-x: auto;}\r\n</style>\r\n<![endif]-->\r\n\r\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/LayoutTopCommon-252919815_https.css" charset="UTF-8" />\r\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning//common/css/music/player-d3fc09e_https.css">\r\n\r\n<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?2" />\r\n\n\n\n\n\n \n\n\t\n\t\t<meta property="og:title" content="\xeb\x86\x80\xeb\x9e\x80 \xeb\x9d\xbc\xec\x9d\xb4\xec\x96\xb8\xec\x9d\x98 \xed\x86\xb5\xec\x82\xb0 5714\xed\x83\x88\xec\x82\xbc\xec\xa7\x84"/>\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t<meta property="og:image" content="https://blogimgs.pstatic.net/nblog/mylog/post/og_default_image_160610.png"/>\n\t\t\t\n\t\t\n        <meta property="og:description" content="\xeb\xa9\x94\xec\x9d\xb4\xec\xa0\x80\xeb\xa6\xac\xea\xb7\xb8 \xea\xb3\xb5\xec\x8b\x9d \xed\x99\x88\xed\x8e\x98\xec\x9d\xb4\xec\xa7\x80\xec\x9d\xb8 MLB.com \xec\x97\x90\xec\x84\x9c \xec\x95\xbc\xea\xb5\xac\xea\xb0\x80 \xec\xa1\xb4\xec\x86\x8d\xed\x95\x98\xeb\x8a\x94 \xed\x95\x9c \xec\x98\x81\xec\x9b\x90\xed\x9e\x88 \xec\xa1\xb4\xec\x86\x8d\xed\x95\xa0 \xeb\xb6\x88\xeb\xa9\xb8\xec\x9d\x98 \xea\xb8\xb0\xeb\xa1\x9d 17\xea\xb0\x9c\xeb\xa5\xbc \xec\x86\x8c\xea\xb0\x9c..."/>\n\n\t\t\n\t\t\t<meta property="og:url" content="https://blog.naver.com/jjys9047/221306678552"/>\n\t\t\n\t\n\t\n\n<meta property="me:feed:serviceId" content="blog" />\r\n<style type="text/css">\r\n/*<![CDATA[*/\r\n\n\nbody {background-color:#A9C6D9;background-image:none;}\r\n#head-skin {background-image:url(https://blogimgs.pstatic.net/nblog/skins/background/1001_head.jpg);}\r\n\n\n#whole-border {border-width:2px;border-style:solid;border-color:rgb(255, 255, 255);background:rgb(255, 255, 255);}\r\n#whole-head {height:6px;background:rgb(255, 255, 255);}\r\n#whole-body {padding:6px;background:rgb(255, 255, 255);}\r\n#whole-footer {height:6px;background:rgb(255, 255, 255);}\r\n\n\n#wrapper .side-border {border-width:0px;border-style:solid;border-color:rgb(0, 0, 0);}\r\n#wrapper .side-head {height:8px;background:transparent;}\r\n#wrapper .side-body {padding:0px;background:transparent;}\r\n#wrapper .side-footer {height:8px;background:transparent;}\r\n\n\n#wrapper .cm-col1 {color:rgb(108, 108, 108);}\r\n#wrapper .cm-arw {background:rgb(108, 108, 108);}\r\n#wrapper div.line {border-top-color:rgb(108, 108, 108);}\r\n#wrapper .cm-border {border-width:0px;border-style:solid;border-color:rgb(0, 0, 0);}\r\n#wrapper .cm-head {height:30px;background:url(https://blogimgs.pstatic.net/nblog/skins/infobox/1005_head.gif);}\r\n#wrapper .cm-body {background:url(https://blogimgs.pstatic.net/nblog/skins/infobox/1005_body.gif);}\r\n#wrapper .cm-footer {height:6px;background:url(https://blogimgs.pstatic.net/nblog/skins/infobox/1005_footer.gif);}\r\n#wrapper .cm-icol {color:rgb(108, 108, 108);}\r\n#wrapper h3 {margin-left:14px;bottom:4px;}\r\n#wrapper .cmore {bottom:4px;}\r\n#blog-category .listimage {background-image:url(https://blogimgs.pstatic.net/nblog/skins/infobox/0003_arw.gif);}\r\n#wrapper .buddyup {background-image:url(https://blogimgs.pstatic.net/nblog/skins/infobox/0003_icon_up.gif);}\r\n#wrapper .buddydw {background-image:url(https://blogimgs.pstatic.net/nblog/skins/infobox/0003_icon_down.gif);}\r\n#blog-category .f_icoclosed {}\r\n#blog-category .f_icoopen {}\r\n#blog-category ul li.depth2 {background-image:url(https://blogimgs.pstatic.net/nblog/skins/infobox/ico_depth2_l.gif) !important;}\r\n\n\n#blog-gnb .link {color:rgb(0, 0, 0);}\r\n#blog-gnb .gnb ...
