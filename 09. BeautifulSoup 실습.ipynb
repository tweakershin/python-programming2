# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.naver.com"
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta property="og:title" content="네이버">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="">\n<meta name="twitter:url" content="https://www.naver.com/">\n<meta name
# ...

# %%
resp.content
# Out:
# b'<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>\n<meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https:/
# ...

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %% [markdown]
# ### prettify()

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %%
soup.prettify()

# %% [markdown]
# ### soup.  \[tag_name]

# %%
soup.title
# Out:
# <title>NAVER</title>

# %%
# 태그 이름
soup.title.name
# Out:
# 'title'

# %%
# 태그 내 문자열
soup.title.string
# Out:
# 'NAVER'

# %%
# 태그 내 문자열
soup.body.string

# %%
soup.title.text
# Out:
# 'NAVER'

# %%
# 태그 내 텍스트 전체
soup.body.text
# Out:
# '\n\n\n연합뉴스 바로가기\n주제별캐스트 바로가기\n타임스퀘어 바로가기\n쇼핑캐스트 바로가기\n로그인 바로가기\n\n\n\n\n\n\n\n\n\n네이버\n\n\n\n네이버를 시작페이지로\n\n쥬니어네이버\n해피빈\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n자동완성 펼치기\n\n검색\n\n\n\n\n한글 입력기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n시간대와 관심사에 맞춘 컨텍스트 자동완성\n도움말 보기\n\n\n\nON선택됨\nOFF\n\n\n컨텍스트 자동완성\n\n동일한 시간대/연령/남녀별 사용자 그룹의관심사에 맞춰 자동완성을 제공합니다.\n\n로그인\n자세히\n\n\n\nON/OFF설정은해당 기기(브라우저)에 저장됩니다.\n\n자세히\n\n\n컨텍스트 자동완성 레이어 닫기\n\n\n\n도움말신고검색어저장 켜기자동완성 끄기\n기능을 다시 켤 때는 자동완성 펼치기을 클릭하세요\n\n\n현재 자동완성 기능을 사용하고 계십니다.\n도움말신고검색어저장 켜기자동완성 끄기\n기능을 다시 켤 때는 자동완성 펼치기을 클릭하세요\n\n\n자동완성 기능이 활성화되었습니다.\n도움말신고검색어저장 켜기자동완성 끄기\n기능을 다시 켤 때는 자동완성 펼치기을 클릭하세요\n\n\n자동완성 기능이 꺼져 있습니다.\n도움말신고검색어저장 켜기자동완성 켜기\n\n\n\n\n\n최근검색어내 검색어\n\n\n내 검색어 등록@txt@@date@.삭제@in_txt@\n최근검색어 내역이 없습니다.\n검색어 저장 기능이 꺼져 있습니다.\n\n\n내 검색어 해제@txt@\n설정된 내 검색어가 없습니다.최근검색어에서 내 검색어 등록를 선택하여 자주 찾는 검색어를내 검색어로 저장해 보세요.\n검색어 저장 기능이 꺼져 있습니다.\n\n알림공용 PC에서는 개인정보 보호를 위하여 반드시 로그아웃을 해 주세요.\n기록 삭제검색어저장 끄기자동완성 끄기\n기록 전체 삭제완료\n기록 전체 삭제검색어저장 끄기자동완성 끄기\n기능을 다시 
# ...

# %%
soup.title.parent
# Out:
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description">
# <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://pm.pstatic.net/css/main_v190523.css" rel="stylesheet" type="text/css"/>
# <link href="https://pm.pstatic.net/css/webfont_v170623.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_181122.css" rel="stylesheet" type="text/css"/>
# <script src="https://pm.pstatic.net/js/c/nlog_v181107.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/tveta/libs/assets/js/common/min/probe.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# var nsc = "navertop.v3";
# document.domain = "naver.com";
# var jindoAll = "";
# var iframeLazyLoad = false;
# if (!!!window.console) {window.console={};window.console["log"]=function(){}}
# var isLogin = false;
# ...

# %%
soup.p
# Out:
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>

# %% [markdown]
# ### 태그의 속성 접근

# %%
# 태그의 속성 접근
soup.p.attrs
# Out:
# {'class': ['dsc']}

# %%
# 태그의 속성 접근2
soup.p['class']
# Out:
# ['dsc']

# %% [markdown]
# ### find_all(tag, 속성) / find(tag, 속성)

# %%
resp = requests.get("https://search.naver.com/search.naver")
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
# soup.find
soup.find('div')
# Out:
# <div id="nxtt_div" style="display:none;position:absolute;border-width:0;z-index:11000"></div>

# %% [markdown]
# ### find_all

# %%
# soup.find_all
soup.find_all('div')
# Out:
# [<div id="nxtt_div" style="display:none;position:absolute;border-width:0;z-index:11000"></div>,
#  <div id="u_skip"> <a href="#lnb"><span>메뉴 영역으로 바로가기</span></a> <a href="#content"><span>본문 영역으로 바로가기</span></a> </div>,
# ...

# %%
len(soup.find_all('div'))
# Out:
# 126

# %% [markdown]
# ##### find_all with list

# %%
# a하고 p 같이 찾기
soup.find_all(['a', 'p'])
# Out:
# [<a href="#lnb"><span>메뉴 영역으로 바로가기</span></a>,
#  <a href="#content"><span>본문 영역으로 바로가기</span></a>,
#  <a class="spnew logo_naver" href="http://www.naver.com" onclick="return goOtherCR(this, 'a=sta.naver&amp;r=&amp;i=&amp;u='+urlencode(this.href));">NAVER</a>,
#  <a class="bt_atcp _btn_arw fold" href="#" onclick="return false;"><span class="blind _text">자동완성 펼치기</span><span class="ico_arrow spnew"></span></a>,
#  <a class="spat ico_info" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a>,
#  <a class="btn_turnon active" href="#" onclick="__atcmpCR(event, this, 'plus.use', '','','');">ON<span class="blind">선택됨</span></a>,
#  <a class="btn_turnoff" href="#" onclick="__atcmpCR(event, this, 'plus.unuse', '','','');">OFF</a>,
#  <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>,
# ...

# %% [markdown]
# ### find_all 갯수 제한

# %%
len(soup.find_all('div', limit=10))

# %% [markdown]
# ### find_all 재귀 X

# %%
len(soup.body.find_all("div", recursive=False))
# Out:
# 3

# %%
soup.body.find_all("div", recursive=False)[2]
# Out:
# <div id="wrap"> <div id="header_wrap" role="heading"> <div class="header_group"> <div class="search_area"> <h1><a class="spnew logo_naver" href="http://www.naver.com" onclick="return goOtherCR(this, 'a=sta.naver&amp;r=&amp;i=&amp;u='+urlencode(this.href));">NAVER</a></h1> <form action="?" id="nx_search_form" method="get" name="search" onsubmit="return nx_form_submit(this)" role="search"> <fieldset class="greenwindow"> <legend>검색</legend> <input name="sm" type="hidden" value="tab_hty.top"/> <input name="where" type="hidden" value="nexearch"/> <div class="greenbox"> <span class="keyword"> <input accesskey="s" autocomplete="off" class="box_window" id="nx_query" maxlength="255" name="query" title="검색어 입력" type="text" value=""/> </span> </div> <input name="oquery" type="hidden" value=""/> <input name="tqi" type="hidden" value="UduVvdpVuE8ssbhsgu0ssssssEd-153625"/> <input disabled="" name="acq" type="hidden" value=""/> <input disabled="" name="acr" type="hidden" value=""/> <input disabled=
# ...

# %% [markdown]
# ### 속성으로 찾기

# %% [markdown]
# ##### 특별한 속성

# %%
soup.find_all(id="main_pack")
# Out:
# [<div class="main_pack" id="main_pack"><script>g_crt+="";</script>
#  <div class="noresult_type3" id="notfound"> <div class="not_found02"> <p><em>''</em>에 대한 검색결과가 없습니다.</p> <ul> <li>단어의 철자가 정확한지 확인해 보세요.</li> <li>한글을 영어로 혹은 영어를 한글로 입력했는지 확인해 보세요.</li> <li>검색어의 단어 수를 줄이거나, 보다 일반적인 검색어로 다시 검색해 보세요.</li> <li>두 단어 이상의 검색어인 경우, 띄어쓰기를 확인해 보세요. <a href="//search.naver.com/search.naver?sm=tab_nex&amp;where=nexearch&amp;query=%EB%84%A4%EC%9D%B4%EB%B2%84+%EB%A7%9E%EC%B6%A4%EB%B2%95+%EA%B2%80%EC%82%AC%EA%B8%B0" onclick="return goOtherCR(this, 'a=nrs.naverlab&amp;r=&amp;i=&amp;u='+urlencode(this.href))">네이버 맞춤법 검사기</a></li> <li>검색 옵션을 변경해서 다시 검색해 보세요.</li> </ul> </div> </div></div>]

# %%
# 속성으로 찾기
realtime_search = soup.find(class_='realtime_srch')
realtime_search
# Out:
# <div class="realtime_srch _aside_news_tab"> <div class="hotkwd"> <ul class="api_realtime_tab _tab"> <li class="selected" data-blind-text="뉴스토픽 뉴스" data-index="0"><a href="#" onclick="return tCR('htk.nws', 1, '');">뉴스</a></li> <li data-blind-text="뉴스토픽 연예·스포츠" data-index="1"><a href="#" onclick="return tCR('htk.ents', 1, '');">연예·스포츠</a></li> </ul> </div> <h6 class="blind _blind">뉴스토픽 뉴스</h6> <ol class="lst_realtime_srch _tab_area"><li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=G
# ...

# %% [markdown]
# ##### 어떤 속성으로든

# %%
realtime_search = soup.find(attrs={'class': 'realtime_srch'})
realtime_search
# Out:
# <div class="realtime_srch _aside_news_tab"> <div class="hotkwd"> <ul class="api_realtime_tab _tab"> <li class="selected" data-blind-text="뉴스토픽 뉴스" data-index="0"><a href="#" onclick="return tCR('htk.nws', 1, '');">뉴스</a></li> <li data-blind-text="뉴스토픽 연예·스포츠" data-index="1"><a href="#" onclick="return tCR('htk.ents', 1, '');">연예·스포츠</a></li> </ul> </div> <h6 class="blind _blind">뉴스토픽 뉴스</h6> <ol class="lst_realtime_srch _tab_area"><li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=G
# ...

# %%
lnb_tag = soup.find(attrs={'href': '#lnb'})
lnb_tag
# Out:
# <a href="#lnb"><span>메뉴 영역으로 바로가기</span></a>

# %%
realtime_ol = realtime_search.find('ol', class_='lst_realtime_srch')
realtime_ol
# Out:
# <ol class="lst_realtime_srch _tab_area"><li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=GS%EA%B1%B4%EC%84%A4+%EC%8B%B1%EA%B0%80%ED%8F%AC%EB%A5%B4+T301%ED%98%84%EC%9E%A5" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=2&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">2</em><span class="tit">GS건설 싱가포르 T301현장</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx bx_item" href="//search
# ...

# %% [markdown]
# ### contents / children for # direct children

# %%
# contents
realtime_ol.contents
# Out:
# [<li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>,
#  <li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=GS%EA%B1%B4%EC%84%A4+%EC%8B%B1%EA%B0%80%ED%8F%AC%EB%A5%B4+T301%ED%98%84%EC%9E%A5" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=2&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">2</em><span class="tit">GS건설 싱가포르 T301현장</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>,
# ...

# %%
len(realtime_ol.contents)

# %%
realtime_ol.children

# %%
# contents와 같은데 iterator로 가져옴.
for li in realtime_ol.children:
    print(li)

# %% [markdown]
# ### .descendants  모든 자손을 가져오자

# %%
realtime_ol.descendants

# %%
for idx, x in enumerate(realtime_ol.descendants):
    print(idx, x)

# %% [markdown]
# ### parents # 바로 부모

# %%
realtime_ol.parent

# %% [markdown]
# ### parents : 조상 generator

# %%
# parents : generator
for idx, parent in enumerate(realtime_ol.parents):
    print(idx, parent.name)

# %% [markdown]
# ### siblings

# %%
# 첫번째 컨텐츠
realtime_contents = realtime_ol.contents
realtime_contents
# Out:
# [<li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>,
#  <li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=GS%EA%B1%B4%EC%84%A4+%EC%8B%B1%EA%B0%80%ED%8F%AC%EB%A5%B4+T301%ED%98%84%EC%9E%A5" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=2&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">2</em><span class="tit">GS건설 싱가포르 T301현장</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>,
# ...

# %%
first = realtime_contents[0]
first
# Out:
# <li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>

# %%
second = first.next_sibling
second
# Out:
# <li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=GS%EA%B1%B4%EC%84%A4+%EC%8B%B1%EA%B0%80%ED%8F%AC%EB%A5%B4+T301%ED%98%84%EC%9E%A5" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=2&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">2</em><span class="tit">GS건설 싱가포르 T301현장</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>

# %%
# 다음 형제들의 generator
for n_siblings in first.next_siblings:
    print(n_siblings)
    print("-"* 10)

# %%
before_second = second.previous_sibling
before_second
# Out:
# <li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>

# %%
# 이전 형제들의 generator
before_siblings = second.previous_siblings
before_siblings

# %% [markdown]
# ### element : 요소로 접근하기 (tree X)

# %%
first.next_element
# Out:
# <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%98%B8%EA%B5%AD%EB%B3%B4%ED%9B%88%EC%9D%98+%EB%8B%AC" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">호국보훈의 달</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a>

# %%
first.next_elements
# Out:
# <generator object next_elements at 0x0000000005F67990>

# %%
first.next_element.next_element

# %%
first.previous_element

# %% [markdown]
# ### find_all with string(문자열로 문자열 찾기)

# %%
news_topics = soup.find_all(string="뉴스토픽")
news_topics

# %%
news_topics[0].parent

# %%
news_topics[1].parent

# %%
news_topics[2].parent

# %% [markdown]
# ### find_next_siblings() // find_next_sibling()
# ### find_previous_siblings() // find_previous_sibling()
#
# 태그 지정해서 sibling 찾기

# %%
ol_tag = first.parent

# %%
ol_tag.find_next_siblings('ol')

# %%
div_tag = ol_tag.find_next_sibling('div')
div_tag

# %%
div_tag.find_previous_siblings('ol')

# %% [markdown]
# ### find_all_next(), find_next()
# ### find_all_previous(), find_previous()
# 태그 지정해서 element 찾기

# %%
div_tag.find_all_next('a')

# %%
div_tag.find_next('a')

# %%
div_tag.find_all_previous('a')

# %%
div_tag.find_previous('a')

# %%
BeautifulSoup?

# %%
requests?

# %% [markdown]
# # BS 정리

# %%
resp = requests.get('https://search.naver.com/search.naver?&where=news&query=무역전쟁')

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
news_topic = soup.find('div', id="nxfr_htp")

# %%
type(news_topic)
# Out:
# bs4.element.Tag

# %%
news_topic_all = soup.find_all('div', id="nxfr_htp")

# %%
type(news_topic_all[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# ### 태그여야만 (find, find_all 등을 사용할 수 있어요.)

# %%
len(news_topic.find('ol'))
# Out:
# 10

# %%
news_topic_all.find('ol')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-74362939bd41> in <module>
# ----> 1 news_topic_all.find('ol')
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
type(news_topic)
# Out:
# bs4.element.Tag

# %%
type(news_topic_all)
# Out:
# bs4.element.ResultSet

# %%
# li찾기
len(news_topic.find_all('li'))
# Out:
# 22

# %%
ol_tags = news_topic.find_all('ol')
len(ol_tags)
# Out:
# 2

# %%
news_ol, sports_ol = ol_tags

# %% [markdown]
# ### news_ol
# ### .contents

# %%
len(news_ol.contents)
# Out:
# 10

# %%
news_ol.contents
# Out:
# [<li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EB%B6%88%EB%B2%95%ED%8F%90%EA%B8%B0%EB%AC%BC+%ED%8A%B9%EB%B3%84%EC%88%98%EC%82%AC%EB%8B%A8+%EB%B0%9C%EC%A1%B1" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">불법폐기물 특별수사단 발족</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>,
#  <li><a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%ED%95%9C%EC%84%A0%EA%B5%90+%EA%B8%B0%EC%9E%90%EB%93%A4+%ED%96%A5%ED%95%B4" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=2&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">2</em><span class="tit">한선교 기자들 향해</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li>,
# ...

# %%
li_list = news_ol.contents

# %%
for item in li_list:
    a_tag = item.find('a')
    # print(item.contents[0])
    # print(item.a)
    print(a_tag)
    print("="*50)
#     print(a_tag.attrs['href'])
    # a_tag['']
    # print(a_tag.text)
    span_tag = a_tag.find('span', class_="tit")
    # print(span_tag)
    span_text = span_tag.text
    print(span_text)
    break
# Out:
# <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EB%B6%88%EB%B2%95%ED%8F%90%EA%B8%B0%EB%AC%BC+%ED%8A%B9%EB%B3%84%EC%88%98%EC%82%AC%EB%8B%A8+%EB%B0%9C%EC%A1%B1" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">불법폐기물 특별수사단 발족</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a>
# ...
# 불법폐기물 특별수사단 발족

# %%
type(li_list[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# # 네이버 블로그 글 읽기

# %% [markdown]
# # Select

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=news&query=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&oquery=%EB%AC%B4%EC%97%AD%EC%A0%84%EC%9F%81&tqi=UdlyIwp0JXosscXzPz4ssssstqN-499407'

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content)

# %%
# class: '.'
# id: '#'
# children: '>' 

# class가 'type01'인 ul 밑에
# id가 'sp_nws1' li태그가 있어요.
# 그리고 그 자식으로 
#'thumb'이라는 클래스가 있습니다.
# 이 때 표현식은 다음과 같아요.
'ul.type01 li#sp_nws1>.thumb'
# Out:
# 'ul.type01 li#sp_nws1>.thumb'

# %%
soup.select('ul.type01 li#sp_nws1>.thumb')
# Out:
# [<div class="thumb"><a class="sp_thmb thmb80" href="http://www.datanet.co.kr/news/articleView.html?idxno=134845" onclick="return goOtherCR(this, 'a=nws*b.img&amp;r=1&amp;i=880005C7_000000000000000000089417&amp;g=5096.0000089417&amp;u='+urlencode(this.href));" target="_blank"><img alt="데이터로봇, 쏘카에 머" class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5096%2F2019%2F06%2F18%2F89417.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div>]

# %%
ul_list = soup.select('ul.type01>li')

# %%
len(ul_list)
# Out:
# 10
